# %%
import pandas as pd

# %%
# Load VH Interaction Partners
df = pd.read_excel('high_confidence_ppi.xlsx', header=1)
df
# Out:
#                 Bait   Preys PreyGene      MIST  Saint_BFDR  AvgSpec  \
# 0        SARS-CoV2 E  O00203    AP3B1  0.963550        0.00     4.67
# 1        SARS-CoV2 E  O60885     BRD4  0.978488        0.00     2.67
# 2        SARS-CoV2 E  P25440     BRD2  0.906593        0.00     7.00
# 3        SARS-CoV2 E  Q6UX04    CWC27  0.893109        0.03     2.67
# 4        SARS-CoV2 E  Q86VM9   ZC3H18  0.796415        0.00     2.67
# ..               ...     ...      ...       ...         ...      ...
# 327  SARS-CoV2 orf9c  Q9Y276    BCS1L  0.992310        0.00    35.00
# 328  SARS-CoV2 orf9c  Q9Y375  NDUFAF1  0.762046        0.00     3.67
# 329  SARS-CoV2 orf9c  Q9Y3A6    TMED5  0.705393        0.05     2.00
# 330  SARS-CoV2 orf9c  Q9Y6M9   NDUFB9  0.966178        0.04     2.33
# 331  SARS-CoV2 orf9c  Q96S52     PIGS  0.647089        0.00    10.67
#
#      FoldChange Uniprot Protein ID  \
# 0         46.67        AP3B1_HUMAN
# 1         26.67         BRD4_HUMAN
# 2         70.00         BRD2_HUMAN
# 3         26.67        CWC27_HUMAN
# 4         26.67        ZCH18_HUMAN
# ..          ...                ...
# 327      350.00         BCS1_HUMAN
# 328       36.67        CIA30_HUMAN
# 329       20.00        TMED5_HUMAN
# 330       23.33        NDUB9_HUMAN
# 331      106.67         PIGS_HUMAN
#
#                            Uniprot Protein Description  \
# 0    AP-3 complex subunit beta-1 (Adaptor protein c...
# 1     Bromodomain-containing protein 4 (Protein HUNK1)
# 2    Bromodomain-containing protein 2 (O27.1.1) (Re...
# 3    Spliceosome-associated protein CWC27 homolog (...
# 4    Zinc finger CCCH domain-containing protein 18 ...
# ..                                                 ...
# 327  Mitochondrial chaperone BCS1 (h-BCS1) (BCS1-li...
# 328  Complex I intermediate-associated protein 30, ...
# 329  Transmembrane emp24 domain-containing protein ...
# 330  NADH dehydrogenase [ubiquinone] 1 beta subcomp...
# 331  GPI transamidase component PIG-S (Phosphatidyl...
#
#                                       Uniprot Function  \
# 0     Subunit of non-clathrin- and clathrin-associa...
# 1     Chromatin reader protein that recognizes and ...
# 2     May play a role in spermatogenesis or follicu...
# 3     As part of the spliceosome, plays a role in p...
# 4                                                  NaN
# ..                                                 ...
# 327   Chaperone necessary for the assembly of mitoc...
# 328   Chaperone protein involved in early stages of...
# 329   Potential role in vesicular protein trafficki...
# 330   Accessory subunit of the mitochondrial membra...
# 331   Component of the GPI transamidase complex. Es...
#
#                                       Structures (PDB)  \
# 0                                                  NaN
# 1    2I8N;2LSP;2MJV;2N3K;2NCZ;2ND0;2ND1;2NNU;2OSS;2...
# 2    1X0J;2DVQ;2DVR;2DVS;2DVV;2E3K;2G4A;2YDW;2YEK;3...
# 3                        2HQ6;4R3E;5Z56;5Z58;6FF4;6FF7
# 4                                                  NaN
# ..                                                 ...
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
# 330                                5XTC;5XTD;5XTH;5XTI
# 331                                                NaN
#
#                            Uniprot Function in Disease
# 0     Hermansky-Pudlak syndrome 2 (HPS2) [MIM:60823...
# 1     Note=A chromosomal aberration involving BRD4 ...
# 2                                                  NaN
# 3     Retinitis pigmentosa with or without skeletal...
# 4                                                  NaN
# ..                                                 ...
# 327   GRACILE syndrome (GRACILE) [MIM:603358]: GRAC...
# 328   Mitochondrial complex I deficiency, nuclear t...
# 329                                                NaN
# 330   Mitochondrial complex I deficiency, nuclear t...
# 331   Glycosylphosphatidylinositol biosynthesis def...
#
# [332 rows x 12 columns]

# %% [markdown]
# # GEMPRO Pipeline
# Parameters:
# * gem_name (str) – The name of your GEM or just your project in general. This will be the name of the main folder that is created in root_dir.
# * root_dir (str) – Path to where the folder named after gem_name will be created. If not provided, directories will not be created and output directories need to be specified for some steps.
# * pdb_file_type (str) – pdb, mmCif, xml, mmtf - file type for files downloaded from the PDB
# * gem (Model) – COBRApy Model object
# * gem_file_path (str) – Path to GEM file
# * gem_file_type (str) – GEM model type - sbml (or xml), mat, or json formats
# * genes_list (list) – List of gene IDs that you want to map
# * genes_and_sequences (dict) – Dictionary of gene IDs and their amino acid sequence strings
# * genome_path (str) – FASTA file of all protein sequences
# * write_protein_fasta_files (bool) – If individual protein FASTA files should be written out
# * description (str) – Description string of your project
# * custom_spont_id (str) – ID of spontaneous genes in a COBRA model which will be ignored for analysis

# %%
from ssbio.pipeline.gempro import GEMPRO
# Out:
# Creating directory /home/arj39/.config/bioservices
# Creating directory /home/arj39/.cache/bioservices
# Welcome to Bioservices
# ======================
# It looks like you do not have a configuration file.
# We are creating one with default values in /home/arj39/.config/bioservices/bioservices.cfg .
# Done

# %%
# Initialise GEMPRO Class
g = GEMPRO(gem_name='vh_ppi', root_dir='gempro', pdb_file_type='pdb',
           gem=None, gem_file_path=None, gem_file_type=None, genes_list=list(df['Uniprot Protein ID']),
           genes_and_sequences=None, genome_path=None, write_protein_fasta_files=None, description=None,
           custom_spont_id=None)

my_gempro.df_uniprot_metadata.head()

# %% [markdown]
# ## Map UniProt Identifiers to Uniprot entries

# %%
# Map uniprot ids and retrieve metadata and sequences
g.uniprot_mapping_and_metadata(model_gene_source='ACC+ID')
print('Missing a UniProt Mapping: ', g.missing_uniprot_mapping)
g.df_uniprot_metadata.head()
# Out:
# A Jupyter Widget
# Missing a UniProt Mapping:  []
#             uniprot  reviewed gene_name       kegg  \
# gene
# AAR2_HUMAN   Q9Y312     False      AAR2  hsa:25980
# AASS_HUMAN   Q9UDR5     False      AASS  hsa:10157
# AATF_HUMAN   Q9NY61     False      AATF  hsa:26574
# ACAD9_HUMAN  Q9H845     False     ACAD9  hsa:28976
# ACADM_HUMAN  P11310     False     ACADM     hsa:34
#
#                                                         refseq  \
# gene
# AAR2_HUMAN   NP_001258803.1;NP_056326.2;XP_006723833.1;XP_0...
# AASS_HUMAN                                         NP_005754.2
# AATF_HUMAN                                         NP_036270.1
# ACAD9_HUMAN                                        NP_054768.2
# ACADM_HUMAN                         NP_000007.1;NP_001120800.1
#
#                                       pdbs                     pfam  \
# gene
# AAR2_HUMAN                             NaN                  PF05282
# AASS_HUMAN        5L76;5L78;5O1N;5O1O;5O1P  PF03435;PF05222;PF16653
# AATF_HUMAN                            5W6A          PF08164;PF13339
# ACAD9_HUMAN                            NaN  PF00441;PF02770;PF02771
# ACADM_HUMAN  1EGC;1EGD;1EGE;1T9G;2A1T;4P13  PF00441;PF02770;PF02771
#
#                                                    description  entry_date  \
# gene
# AAR2_HUMAN                                Protein AAR2 homolog  2020-04-22
# AASS_HUMAN   Alpha-aminoadipic semialdehyde synthase, mitoc...  2020-04-22
# AATF_HUMAN                                        Protein AATF  2020-04-22
# ACAD9_HUMAN     Complex I assembly factor ACAD9, mitochondrial  2020-04-22
# ACADM_HUMAN  Medium-chain specific acyl-CoA dehydrogenase, ...  2020-04-22
#
#              entry_version    seq_date  seq_version sequence_file  \
# gene
# AAR2_HUMAN             151  2002-10-19            2  Q9Y312.fasta
# AASS_HUMAN             162  2000-05-01            1  Q9UDR5.fasta
# AATF_HUMAN             165  2000-10-01            1  Q9NY61.fasta
# ACAD9_HUMAN            171  2001-03-01            1  Q9H845.fasta
# ACADM_HUMAN            220  1989-07-01            1  P11310.fasta
#
#             metadata_file
# gene
# AAR2_HUMAN     Q9Y312.xml
# AASS_HUMAN     Q9UDR5.xml
# AATF_HUMAN     Q9NY61.xml
# ACAD9_HUMAN    Q9H845.xml
# ACADM_HUMAN    P11310.xml

# %%
# Set representative sequences
g.set_representative_sequence()
print('Missing a representative sequence: ', g.missing_representative_sequence)
g.df_representative_sequences.head()
# Out:
# A Jupyter Widget
# Missing a representative sequence:  []
#             uniprot       kegg                           pdbs sequence_file  \
# gene
# AAR2_HUMAN   Q9Y312  hsa:25980                            NaN  Q9Y312.fasta
# AASS_HUMAN   Q9UDR5  hsa:10157       5L76;5L78;5O1N;5O1O;5O1P  Q9UDR5.fasta
# AATF_HUMAN   Q9NY61  hsa:26574                           5W6A  Q9NY61.fasta
# ACAD9_HUMAN  Q9H845  hsa:28976                            NaN  Q9H845.fasta
# ACADM_HUMAN  P11310     hsa:34  1EGC;1EGD;1EGE;1T9G;2A1T;4P13  P11310.fasta
#
#             metadata_file
# gene
# AAR2_HUMAN     Q9Y312.xml
# AASS_HUMAN     Q9UDR5.xml
# AATF_HUMAN     Q9NY61.xml
# ACAD9_HUMAN    Q9H845.xml
# ACADM_HUMAN    P11310.xml

# %% [markdown]
# ## Get PDB files

# %%
# Map uniprots to PDBs
g.map_uniprot_to_pdb(seq_ident_cutoff=0.7)
print('Missing PDB mapping: ', g.missing_pdb_structures)
g.df_pdb_ranking.head()
# Out:
# A Jupyter Widget
# Missing PDB mapping:  ['EMC1_HUMAN', 'TRI59_HUMAN', 'GBG5_HUMAN', 'FXL12_HUMAN', 'AKAP9_HUMAN', 'HYOU1_HUMAN', 'CLIP4_HUMAN', 'GCC1_HUMAN', 'NDUF2_HUMAN', 'MYCB2_HUMAN', 'CE112_HUMAN', 'ALG8_HUMAN', 'MPPA_HUMAN', 'ACSL3_HUMAN', 'PIGO_HUMAN', 'CLCC1_HUMAN', 'PGES2_HUMAN', 'CNTRL_HUMAN', 'SBNO1_HUMAN', 'FBLN5_HUMAN', 'INHBE_HUMAN', 'DDX21_HUMAN', 'D19L1_HUMAN', 'ZN503_HUMAN', 'STC2_HUMAN', 'TYSD1_HUMAN', 'PLOD2_HUMAN', 'AKP8L_HUMAN', 'AAR2_HUMAN', 'NAT14_HUMAN', 'TMED5_HUMAN', 'ANO6_HUMAN', 'CK5P2_HUMAN', 'REEP5_HUMAN', 'NEUR1_HUMAN', 'UBP2L_HUMAN', 'S27A2_HUMAN', 'ODC_HUMAN', 'ATP5L_HUMAN', 'GT251_HUMAN', 'GOGA7_HUMAN', 'HS2ST_HUMAN', 'TM39B_HUMAN', 'MTCH1_HUMAN', 'CEP68_HUMAN', 'UBAP2_HUMAN', 'CA050_HUMAN', 'PCSK6_HUMAN', 'ERLEC_HUMAN', 'DCAF7_HUMAN', 'ZNT6_HUMAN', 'ALG5_HUMAN', 'CO6A1_HUMAN', 'CTL2_HUMAN', 'MOGS_HUMAN', 'ATE1_HUMAN', 'TOM70_HUMAN', 'ERMP1_HUMAN', 'FKB10_HUMAN', 'FACR2_HUMAN', 'TM2D3_HUMAN', 'PIGS_HUMAN', 'TIM14_HUMAN', 'SCRB1_HUMAN', 'VKGC_HUMAN', 'PUSL1_HUMAN', 'Z3H7A_HUMAN', 'DPH5_HUMAN', 'SYTM_HUMAN', 'WFS1_HUMAN', 'NUP88_HUMAN', 'SMOC1_HUMAN', 'STOM_HUMAN', 'STML2_HUMAN', 'DJC11_HUMAN', 'UBP54_HUMAN', 'TLE5_HUMAN', 'CE350_HUMAN', 'JKIP1_HUMAN', 'BCKD_HUMAN', 'AT1B1_HUMAN', 'MFGM_HUMAN', 'GOGA3_HUMAN', 'CTRO_HUMAN', 'TIM8B_HUMAN', 'PLD3_HUMAN', 'COQ8B_HUMAN', 'ALG11_HUMAN', 'PKHF2_HUMAN', 'PKHA5_HUMAN', 'AT133_HUMAN', 'TIM29_HUMAN', 'FKB15_HUMAN', 'VPS11_HUMAN', 'ERO1B_HUMAN', 'GPAA1_HUMAN', 'BCS1_HUMAN', 'YIF1A_HUMAN', 'NPTX1_HUMAN', 'PABP4_HUMAN', 'CP250_HUMAN', 'ACAD9_HUMAN', 'G3BP2_HUMAN', 'HEAT3_HUMAN', 'RADI_HUMAN', 'NFIP2_HUMAN', 'RB6I2_HUMAN', 'RBM41_HUMAN', 'PO210_HUMAN', 'F162A_HUMAN', 'DDX10_HUMAN', 'AR6P6_HUMAN', 'FXRD2_HUMAN', 'PCNT_HUMAN', 'CCD86_HUMAN', 'TLE3_HUMAN', 'ADAS_HUMAN', 'CRTC3_HUMAN', 'INT4_HUMAN', 'LYOX_HUMAN', 'DCAKD_HUMAN', 'UGGG2_HUMAN', 'BZW2_HUMAN', 'MOV10_HUMAN', 'REEP6_HUMAN', 'AKAP8_HUMAN', 'CHSS2_HUMAN', 'WASC4_HUMAN', 'GRPE1_HUMAN', 'GOGB1_HUMAN', 'EDEM3_HUMAN', 'TBKB1_HUMAN', 'IF4H_HUMAN', 'SCPDL_HUMAN', 'SDF2_HUMAN', 'PDZ11_HUMAN', 'NOL10_HUMAN', 'FAKD5_HUMAN', 'PLGT2_HUMAN', 'AP3B1_HUMAN', 'PLGT3_HUMAN', 'SGMR2_HUMAN', 'VATA_HUMAN', 'T10B_HUMAN', 'LMAN2_HUMAN', 'ZY11B_HUMAN', 'NINL_HUMAN', 'SYNM_HUMAN', 'UBXN8_HUMAN', 'MDN1_HUMAN', 'ZN318_HUMAN', 'ADAM9_HUMAN', 'MA7D1_HUMAN', 'SAAL1_HUMAN', 'MPPB_HUMAN', 'AP2A2_HUMAN', 'GHITM_HUMAN', 'ZNT9_HUMAN', 'RBM28_HUMAN', 'SCAP_HUMAN', 'CHM2A_HUMAN', 'MPP10_HUMAN', 'VAS1_HUMAN', 'QSOX2_HUMAN', 'CHPF2_HUMAN', 'NGDN_HUMAN', 'HOOK1_HUMAN', 'ECSIT_HUMAN', 'CIA30_HUMAN', 'H6ST2_HUMAN', 'ZNT7_HUMAN', 'TRM1_HUMAN', 'NIN_HUMAN', 'ZDHC5_HUMAN', 'PKP2_HUMAN', 'DCTP1_HUMAN', 'TAPT1_HUMAN', 'CENPF_HUMAN', 'GRAP1_HUMAN', 'ERGI1_HUMAN', 'FKBP7_HUMAN', 'MYOME_HUMAN', 'VPS39_HUMAN', 'FA8A1_HUMAN', 'KAP3_HUMAN', 'MIPO1_HUMAN', 'PRC2B_HUMAN', 'ZCH18_HUMAN', 'FBN2_HUMAN', 'SIL1_HUMAN', 'RETR3_HUMAN', 'LAR4B_HUMAN', 'FA98A_HUMAN']
#             pdb_id pdb_chain_id uniprot experimental_method  resolution  \
# gene
# AASS_HUMAN    5l78            A  Q9UDR5   X-ray diffraction        2.68
# AASS_HUMAN    5o1n            A  Q9UDR5   X-ray diffraction        2.28
# AASS_HUMAN    5o1o            B  Q9UDR5   X-ray diffraction        2.48
# AATF_HUMAN    5w6a            F  Q9NY61   X-ray diffraction        1.74
# ACADM_HUMAN   4p13            A  P11310   X-ray diffraction        1.73
#
#              coverage  start  end  unp_start  unp_end  rank
# gene
# AASS_HUMAN      0.510     26  497        455      926     3
# AASS_HUMAN      0.510     26  497        455      926     1
# AASS_HUMAN      0.510     26  497        455      926     2
# AATF_HUMAN      0.016      1    9        539      547     1
# ACADM_HUMAN     0.919      1  387         35      421    21

# %%
# Mapping missing structures using BLAST
g.blast_seqs_to_pdb(all_genes=False, seq_ident_cutoff=0.7, evalue=0.00001)
g.df_pdb_blast.head(2)
# Out:
# A Jupyter Widget
#            pdb_id pdb_chain_id  hit_score  hit_evalue  hit_percent_similar  \
# gene
# ADAS_HUMAN   5ae3            D     3195.0         0.0             0.896657
# ADAS_HUMAN   5ae3            A     3195.0         0.0             0.896657
#
#             hit_percent_ident  hit_num_ident  hit_num_similar  \
# gene
# ADAS_HUMAN           0.866261            570              590
# ADAS_HUMAN           0.866261            570              590
#
#             hit_percent_gaps  hit_num_gaps
# gene
# ADAS_HUMAN               NaN           NaN
# ADAS_HUMAN               NaN           NaN

# %%
# Download available PDBs that have been mapped
g.pdb_downloader_and_metadata(pdb_file_type='mmCif', force_rerun=True)
# Out:
# A Jupyter Widget

# %%
# Set Representative Structures
g.set_representative_structure()
# Out:
# A Jupyter Widget
# 5hk1-A: alignment failed to run, unable to check structure's chain
# 5hk1-B: alignment failed to run, unable to check structure's chain
# 5hk1-C: alignment failed to run, unable to check structure's chain
# Q99720-5hk1: unable to check chain "A"
# Q99720-5hk1: unable to check chain "B"
# Q99720-5hk1: unable to check chain "C"
# 6dk0-A: alignment failed to run, unable to check structure's chain
# 6dk0-B: alignment failed to run, unable to check structure's chain
# 6dk0-C: alignment failed to run, unable to check structure's chain
# Q99720-6dk0: unable to check chain "A"
# Q99720-6dk0: unable to check chain "B"
# Q99720-6dk0: unable to check chain "C"
# 6djz-A: alignment failed to run, unable to check structure's chain
# 6djz-B: alignment failed to run, unable to check structure's chain
# 6djz-C: alignment failed to run, unable to check structure's chain
# Q99720-6djz: unable to check chain "A"
# Q99720-6djz: unable to check chain "B"
# Q99720-6djz: unable to check chain "C"
# 6dk1-A: alignment failed to run, unable to check structure's chain
# 6dk1-B: alignment failed to run, unable to check structure's chain
# 6dk1-C: alignment failed to run, unable to check structure's chain
# Q99720-6dk1: unable to check chain "A"
# Q99720-6dk1: unable to check chain "B"
# Q99720-6dk1: unable to check chain "C"
# 5hk2-A: alignment failed to run, unable to check structure's chain
# 5hk2-B: alignment failed to run, unable to check structure's chain
# 5hk2-C: alignment failed to run, unable to check structure's chain
# Q99720-5hk2: unable to check chain "A"
# Q99720-5hk2: unable to check chain "B"
# Q99720-5hk2: unable to check chain "C"
# SGMR1_HUMAN: no structures meet quality checks
# 2nn6-G: alignment failed to run, unable to check structure's chain
# Q9NQT5-2nn6: unable to check chain "G"
# 6d6q-G: alignment failed to run, unable to check structure's chain
# Q9NQT5-6d6q: unable to check chain "G"
# 6d6r-G: alignment failed to run, unable to check structure's chain
# Q9NQT5-6d6r: unable to check chain "G"
# 6h25-G: alignment failed to run, unable to check structure's chain
# Q9NQT5-6h25: unable to check chain "G"
# EXOS3_HUMAN: no structures meet quality checks
# 4f02-D: alignment failed to run, unable to check structure's chain
# P11940-4f02: unable to check chain "D"
# 1cvj-B: alignment failed to run, unable to check structure's chain
# 1cvj-D: alignment failed to run, unable to check structure's chain
# 1cvj-F: alignment failed to run, unable to check structure's chain
# 1cvj-H: alignment failed to run, unable to check structure's chain
# P11940-1cvj: unable to check chain "B"
# P11940-1cvj: unable to check chain "D"
# P11940-1cvj: unable to check chain "F"
# P11940-1cvj: unable to check chain "H"
# 4f25-A: alignment failed to run, unable to check structure's chain
# P11940-4f25: unable to check chain "A"
# 1jgn-A: alignment failed to run, unable to check structure's chain
# P11940-1jgn: unable to check chain "A"
# 2k8g-A: alignment failed to run, unable to check structure's chain
# P11940-2k8g: unable to check chain "A"
# 3kuj-A: alignment failed to run, unable to check structure's chain
# P11940-3kuj: unable to check chain "A"
# 3kus-B: alignment failed to run, unable to check structure's chain
# P11940-3kus: unable to check chain "B"
# 3kut-A: alignment failed to run, unable to check structure's chain
# P11940-3kut: unable to check chain "A"
# 3ktr-A: alignment failed to run, unable to check structure's chain
# P11940-3ktr: unable to check chain "A"
# 3kui-A: alignment failed to run, unable to check structure's chain
# P11940-3kui: unable to check chain "A"
# 2rqh-B: alignment failed to run, unable to check structure's chain
# P11940-2rqh: unable to check chain "B"
# 2x04-A: alignment failed to run, unable to check structure's chain
# P11940-2x04: unable to check chain "A"
# 3kur-A: alignment failed to run, unable to check structure's chain
# 3kur-C: alignment failed to run, unable to check structure's chain
# 3kur-E: alignment failed to run, unable to check structure's chain
# 3kur-G: alignment failed to run, unable to check structure's chain
# P11940-3kur: unable to check chain "A"
# P11940-3kur: unable to check chain "C"
# P11940-3kur: unable to check chain "E"
# P11940-3kur: unable to check chain "G"
# 5dx1-F: alignment failed to run, unable to check structure's chain
# 5dx1-H: alignment failed to run, unable to check structure's chain
# P11940-5dx1: unable to check chain "F"
# P11940-5dx1: unable to check chain "H"
# 5dx8-E: alignment failed to run, unable to check structure's chain
# 5dx8-G: alignment failed to run, unable to check structure's chain
# P11940-5dx8: unable to check chain "E"
# P11940-5dx8: unable to check chain "G"
# 5dxa-F: alignment failed to run, unable to check structure's chain
# 5dxa-I: alignment failed to run, unable to check structure's chain
# P11940-5dxa: unable to check chain "F"
# P11940-5dxa: unable to check chain "I"
# 5lgr-F: alignment failed to run, unable to check structure's chain
# 5lgr-H: alignment failed to run, unable to check structure's chain
# P11940-5lgr: unable to check chain "F"
# P11940-5lgr: unable to check chain "H"
# 5lgp-F: alignment failed to run, unable to check structure's chain
# 5lgp-H: alignment failed to run, unable to check structure's chain
# P11940-5lgp: unable to check chain "F"
# P11940-5lgp: unable to check chain "H"
# 5lgq-F: alignment failed to run, unable to check structure's chain
# 5lgq-H: alignment failed to run, unable to check structure's chain
# P11940-5lgq: unable to check chain "F"
# P11940-5lgq: unable to check chain "H"
# 5lgs-F: alignment failed to run, unable to check structure's chain
# 5lgs-H: alignment failed to run, unable to check structure's chain
# P11940-5lgs: unable to check chain "F"
# P11940-5lgs: unable to check chain "H"
# PABP1_HUMAN: no structures meet quality checks
# 1z0a-A: alignment failed to run, unable to check structure's chain
# 1z0a-B: alignment failed to run, unable to check structure's chain
# 1z0a-C: alignment failed to run, unable to check structure's chain
# 1z0a-D: alignment failed to run, unable to check structure's chain
# P61019-1z0a: unable to check chain "A"
# P61019-1z0a: unable to check chain "B"
# P61019-1z0a: unable to check chain "C"
# P61019-1z0a: unable to check chain "D"
# RAB2A_HUMAN: no structures meet quality checks
# 6bnt-A: alignment failed to run, unable to check structure's chain
# Q96CW1-6bnt: unable to check chain "A"
# AP2M1_HUMAN: no structures meet quality checks
# 6hmd-A: alignment failed to run, unable to check structure's chain
# P19784-6hmd: unable to check chain "A"
# 6hmc-A: alignment failed to run, unable to check structure's chain
# P19784-6hmc: unable to check chain "A"
# 6hmb-A: alignment failed to run, unable to check structure's chain
# P19784-6hmb: unable to check chain "A"
# 5ooi-A: alignment failed to run, unable to check structure's chain
# 5ooi-B: alignment failed to run, unable to check structure's chain
# P19784-5ooi: unable to check chain "A"
# P19784-5ooi: unable to check chain "B"
# 3ofm-A: alignment failed to run, unable to check structure's chain
# P19784-3ofm: unable to check chain "A"
# 5m4u-A: alignment failed to run, unable to check structure's chain
# P19784-5m4u: unable to check chain "A"
# 5m56-A: alignment failed to run, unable to check structure's chain
# 5m56-B: alignment failed to run, unable to check structure's chain
# P19784-5m56: unable to check chain "A"
# P19784-5m56: unable to check chain "B"
# 6hmq-A: alignment failed to run, unable to check structure's chain
# P19784-6hmq: unable to check chain "A"
# 6qy9-A: alignment failed to run, unable to check structure's chain
# P19784-6qy9: unable to check chain "A"
# 6qy8-A: alignment failed to run, unable to check structure's chain
# 6qy8-B: alignment failed to run, unable to check structure's chain
# 6qy8-C: alignment failed to run, unable to check structure's chain
# 6qy8-D: alignment failed to run, unable to check structure's chain
# P19784-6qy8: unable to check chain "A"
# P19784-6qy8: unable to check chain "B"
# P19784-6qy8: unable to check chain "C"
# P19784-6qy8: unable to check chain "D"
# 5yf9-B: alignment failed to run, unable to check structure's chain
# 5yf9-X: alignment failed to run, unable to check structure's chain
# P19784-5yf9: unable to check chain "B"
# P19784-5yf9: unable to check chain "X"
# 5ywm-X: alignment failed to run, unable to check structure's chain
# P19784-5ywm: unable to check chain "X"
# 5y9m-A: alignment failed to run, unable to check structure's chain
# 5y9m-X: alignment failed to run, unable to check structure's chain
# P19784-5y9m: unable to check chain "A"
# P19784-5y9m: unable to check chain "X"
# 3e3b-X: alignment failed to run, unable to check structure's chain
# P19784-3e3b: unable to check chain "X"
# 6l20-A: alignment failed to run, unable to check structure's chain
# 6l20-D: alignment failed to run, unable to check structure's chain
# 6l20-G: alignment failed to run, unable to check structure's chain
# 6l20-J: alignment failed to run, unable to check structure's chain
# P19784-6l20: unable to check chain "A"
# P19784-6l20: unable to check chain "D"
# P19784-6l20: unable to check chain "G"
# P19784-6l20: unable to check chain "J"
# 3u87-B: alignment failed to run, unable to check structure's chain
# P19784-3u87: unable to check chain "B"
# CSK22_HUMAN: no structures meet quality checks
# 3qe2-A: alignment failed to run, unable to check structure's chain
# 3qe2-B: alignment failed to run, unable to check structure's chain
# P16435-3qe2: unable to check chain "A"
# P16435-3qe2: unable to check chain "B"
# 3qfc-A: alignment failed to run, unable to check structure's chain
# 3qfc-B: alignment failed to run, unable to check structure's chain
# P16435-3qfc: unable to check chain "A"
# P16435-3qfc: unable to check chain "B"
# 5emn-A: alignment failed to run, unable to check structure's chain
# 5emn-B: alignment failed to run, unable to check structure's chain
# P16435-5emn: unable to check chain "A"
# P16435-5emn: unable to check chain "B"
# 5fa6-A: alignment failed to run, unable to check structure's chain
# 5fa6-B: alignment failed to run, unable to check structure's chain
# P16435-5fa6: unable to check chain "A"
# P16435-5fa6: unable to check chain "B"
# 3qfr-A: alignment failed to run, unable to check structure's chain
# 3qfr-B: alignment failed to run, unable to check structure's chain
# P16435-3qfr: unable to check chain "A"
# P16435-3qfr: unable to check chain "B"
# 3fjo-A: alignment failed to run, unable to check structure's chain
# P16435-3fjo: unable to check chain "A"
# 3qft-A: alignment failed to run, unable to check structure's chain
# P16435-3qft: unable to check chain "A"
# NCPR_HUMAN: no structures meet quality checks
# 2jgb-A: alignment failed to run, unable to check structure's chain
# O60573-2jgb: unable to check chain "A"
# 5xln-A: alignment failed to run, unable to check structure's chain
# O60573-5xln: unable to check chain "A"
# 2jgc-A: alignment failed to run, unable to check structure's chain
# O60573-2jgc: unable to check chain "A"
# 5nvn-A: alignment failed to run, unable to check structure's chain
# 5nvn-C: alignment failed to run, unable to check structure's chain
# O60573-5nvn: unable to check chain "A"
# O60573-5nvn: unable to check chain "C"
# 5nvm-A: alignment failed to run, unable to check structure's chain
# 5nvm-C: alignment failed to run, unable to check structure's chain
# O60573-5nvm: unable to check chain "A"
# O60573-5nvm: unable to check chain "C"
# 5nvl-A: alignment failed to run, unable to check structure's chain
# 5nvl-C: alignment failed to run, unable to check structure's chain
# O60573-5nvl: unable to check chain "A"
# O60573-5nvl: unable to check chain "C"
# 5nvk-A: alignment failed to run, unable to check structure's chain
# 5nvk-C: alignment failed to run, unable to check structure's chain
# 5nvk-E: alignment failed to run, unable to check structure's chain
# 5nvk-G: alignment failed to run, unable to check structure's chain
# O60573-5nvk: unable to check chain "A"
# O60573-5nvk: unable to check chain "C"
# O60573-5nvk: unable to check chain "E"
# O60573-5nvk: unable to check chain "G"
# IF4E2_HUMAN: no structures meet quality checks
# 3bbp-E: alignment failed to run, unable to check structure's chain
# Q8IWJ2-3bbp: unable to check chain "E"
# GCC2_HUMAN: no structures meet quality checks
# 5w6a-F: alignment failed to run, unable to check structure's chain
# Q9NY61-5w6a: unable to check chain "F"
# AATF_HUMAN: no structures meet quality checks
# 2pbj-A: alignment failed to run, unable to check structure's chain
# 2pbj-B: alignment failed to run, unable to check structure's chain
# 2pbj-C: alignment failed to run, unable to check structure's chain
# 2pbj-D: alignment failed to run, unable to check structure's chain
# Q9H7Z7-2pbj: unable to check chain "A"
# Q9H7Z7-2pbj: unable to check chain "B"
# Q9H7Z7-2pbj: unable to check chain "C"
# Q9H7Z7-2pbj: unable to check chain "D"
# 1z9h-A: alignment failed to run, unable to check structure's chain
# 1z9h-B: alignment failed to run, unable to check structure's chain
# 1z9h-C: alignment failed to run, unable to check structure's chain
# 1z9h-D: alignment failed to run, unable to check structure's chain
# Q9H7Z7-1z9h: unable to check chain "A"
# Q9H7Z7-1z9h: unable to check chain "B"
# Q9H7Z7-1z9h: unable to check chain "C"
# Q9H7Z7-1z9h: unable to check chain "D"
# PGES2_HUMAN: no structures meet quality checks
# 4u7i-A: alignment failed to run, unable to check structure's chain
# Q8N0X7-4u7i: unable to check chain "A"
# SPART_HUMAN: no structures meet quality checks
# 5bwl-A: alignment failed to run, unable to check structure's chain
# Q9NXA8-5bwl: unable to check chain "A"
# 6eqs-A: alignment failed to run, unable to check structure's chain
# 6eqs-B: alignment failed to run, unable to check structure's chain
# 6eqs-C: alignment failed to run, unable to check structure's chain
# 6eqs-D: alignment failed to run, unable to check structure's chain
# Q9NXA8-6eqs: unable to check chain "A"
# Q9NXA8-6eqs: unable to check chain "B"
# Q9NXA8-6eqs: unable to check chain "C"
# Q9NXA8-6eqs: unable to check chain "D"
# 3riy-A: alignment failed to run, unable to check structure's chain
# 3riy-B: alignment failed to run, unable to check structure's chain
# Q9NXA8-3riy: unable to check chain "A"
# Q9NXA8-3riy: unable to check chain "B"
# 4f56-A: alignment failed to run, unable to check structure's chain
# 4f56-B: alignment failed to run, unable to check structure's chain
# Q9NXA8-4f56: unable to check chain "A"
# Q9NXA8-4f56: unable to check chain "B"
# 6aco-A: alignment failed to run, unable to check structure's chain
# Q9NXA8-6aco: unable to check chain "A"
# 2b4y-A: alignment failed to run, unable to check structure's chain
# 2b4y-B: alignment failed to run, unable to check structure's chain
# 2b4y-C: alignment failed to run, unable to check structure's chain
# 2b4y-D: alignment failed to run, unable to check structure's chain
# Q9NXA8-2b4y: unable to check chain "A"
# Q9NXA8-2b4y: unable to check chain "B"
# Q9NXA8-2b4y: unable to check chain "C"
# Q9NXA8-2b4y: unable to check chain "D"
# 3rig-A: alignment failed to run, unable to check structure's chain
# 3rig-B: alignment failed to run, unable to check structure's chain
# Q9NXA8-3rig: unable to check chain "A"
# Q9NXA8-3rig: unable to check chain "B"
# 4f4u-A: alignment failed to run, unable to check structure's chain
# 4f4u-B: alignment failed to run, unable to check structure's chain
# Q9NXA8-4f4u: unable to check chain "A"
# Q9NXA8-4f4u: unable to check chain "B"
# 2nyr-A: alignment failed to run, unable to check structure's chain
# 2nyr-B: alignment failed to run, unable to check structure's chain
# Q9NXA8-2nyr: unable to check chain "A"
# Q9NXA8-2nyr: unable to check chain "B"
# 5xhs-A: alignment failed to run, unable to check structure's chain
# Q9NXA8-5xhs: unable to check chain "A"
# 4hda-A: alignment failed to run, unable to check structure's chain
# 4hda-B: alignment failed to run, unable to check structure's chain
# Q9NXA8-4hda: unable to check chain "A"
# Q9NXA8-4hda: unable to check chain "B"
# 6acl-A: alignment failed to run, unable to check structure's chain
# Q9NXA8-6acl: unable to check chain "A"
# 4g1c-A: alignment failed to run, unable to check structure's chain
# 4g1c-B: alignment failed to run, unable to check structure's chain
# Q9NXA8-4g1c: unable to check chain "A"
# Q9NXA8-4g1c: unable to check chain "B"
# 6ace-A: alignment failed to run, unable to check structure's chain
# Q9NXA8-6ace: unable to check chain "A"
# 6acp-A: alignment failed to run, unable to check structure's chain
# Q9NXA8-6acp: unable to check chain "A"
# SIR5_HUMAN: no structures meet quality checks
# 6icz-Z: alignment failed to run, unable to check structure's chain
# O95391-6icz: unable to check chain "Z"
# 6qdv: structure file could not be downloaded in pdb format
# 5xjc: structure file could not be downloaded in pdb format
# SLU7_HUMAN: no structures meet quality checks
# 3zke-D: alignment failed to run, unable to check structure's chain
# 3zke-H: alignment failed to run, unable to check structure's chain
# 3zke-L: alignment failed to run, unable to check structure's chain
# Q8TD19-3zke: unable to check chain "D"
# Q8TD19-3zke: unable to check chain "H"
# Q8TD19-3zke: unable to check chain "L"
# 3zkf-D: alignment failed to run, unable to check structure's chain
# 3zkf-H: alignment failed to run, unable to check structure's chain
# 3zkf-L: alignment failed to run, unable to check structure's chain
# Q8TD19-3zkf: unable to check chain "D"
# Q8TD19-3zkf: unable to check chain "H"
# Q8TD19-3zkf: unable to check chain "L"
# NEK9_HUMAN: no structures meet quality checks
# 3ner-B: alignment failed to run, unable to check structure's chain
# O43169-3ner: unable to check chain "B"
# CYB5B_HUMAN: no structures meet quality checks
# 2bov-A: alignment failed to run, unable to check structure's chain
# P11233-2bov: unable to check chain "A"
# 6p0i-B: alignment failed to run, unable to check structure's chain
# P11233-6p0i: unable to check chain "B"
# 6p0l-B: alignment failed to run, unable to check structure's chain
# P11233-6p0l: unable to check chain "B"
# 6p0j-B: alignment failed to run, unable to check structure's chain
# P11233-6p0j: unable to check chain "B"
# 6p0k-B: alignment failed to run, unable to check structure's chain
# P11233-6p0k: unable to check chain "B"
# 6p0m-B: alignment failed to run, unable to check structure's chain
# P11233-6p0m: unable to check chain "B"
# 6p0o-B: alignment failed to run, unable to check structure's chain
# P11233-6p0o: unable to check chain "B"
# 6p0n-B: alignment failed to run, unable to check structure's chain
# P11233-6p0n: unable to check chain "B"
# 2a9k-A: alignment failed to run, unable to check structure's chain
# P11233-2a9k: unable to check chain "A"
# 2a78-A: alignment failed to run, unable to check structure's chain
# P11233-2a78: unable to check chain "A"
# 1zc3-A: alignment failed to run, unable to check structure's chain
# 1zc3-C: alignment failed to run, unable to check structure's chain
# P11233-1zc3: unable to check chain "A"
# P11233-1zc3: unable to check chain "C"
# 1uad-A: alignment failed to run, unable to check structure's chain
# 1uad-B: alignment failed to run, unable to check structure's chain
# P11233-1uad: unable to check chain "A"
# P11233-1uad: unable to check chain "B"
# 1zc4-A: alignment failed to run, unable to check structure's chain
# 1zc4-C: alignment failed to run, unable to check structure's chain
# P11233-1zc4: unable to check chain "A"
# P11233-1zc4: unable to check chain "C"
# RALA_HUMAN: no structures meet quality checks
# 5xgc-A: alignment failed to run, unable to check structure's chain
# P52306-5xgc: unable to check chain "A"
# 5zhx-A: alignment failed to run, unable to check structure's chain
# 5zhx-B: alignment failed to run, unable to check structure's chain
# 5zhx-C: alignment failed to run, unable to check structure's chain
# 5zhx-D: alignment failed to run, unable to check structure's chain
# P52306-5zhx: unable to check chain "A"
# P52306-5zhx: unable to check chain "B"
# P52306-5zhx: unable to check chain "C"
# P52306-5zhx: unable to check chain "D"
# GDS1_HUMAN: no structures meet quality checks
# 5wrw-A: alignment failed to run, unable to check structure's chain
# 5wrw-C: alignment failed to run, unable to check structure's chain
# 5wrw-E: alignment failed to run, unable to check structure's chain
# O76094-5wrw: unable to check chain "A"
# O76094-5wrw: unable to check chain "C"
# O76094-5wrw: unable to check chain "E"
# 5m72-A: alignment failed to run, unable to check structure's chain
# O76094-5m72: unable to check chain "A"
# 5m73-H: alignment failed to run, unable to check structure's chain
# O76094-5m73: unable to check chain "H"
# SRP72_HUMAN: no structures meet quality checks
# 5nan-C: alignment failed to run, unable to check structure's chain
# Q96F46-5nan: unable to check chain "C"
# 4hsa-C: alignment failed to run, unable to check structure's chain
# Q96F46-4hsa: unable to check chain "C"
# 3jvf-C: alignment failed to run, unable to check structure's chain
# Q96F46-3jvf: unable to check chain "C"
# I17RA_HUMAN: no structures meet quality checks
# 6ff4-s: alignment failed to run, unable to check structure's chain
# Q6UX04-6ff4: unable to check chain "s"
# 6ff7-s: alignment failed to run, unable to check structure's chain
# Q6UX04-6ff7: unable to check chain "s"
# 5z58-z: alignment failed to run, unable to check structure's chain
# Q6UX04-5z58: unable to check chain "z"
# 5z56: structure file could not be downloaded in pdb format
# 2hq6-A: alignment failed to run, unable to check structure's chain
# Q6UX04-2hq6: unable to check chain "A"
# CWC27_HUMAN: no structures meet quality checks
# 1vcb-B: alignment failed to run, unable to check structure's chain
# 1vcb-E: alignment failed to run, unable to check structure's chain
# 1vcb-H: alignment failed to run, unable to check structure's chain
# 1vcb-K: alignment failed to run, unable to check structure's chain
# Q15369-1vcb: unable to check chain "B"
# Q15369-1vcb: unable to check chain "E"
# Q15369-1vcb: unable to check chain "H"
# Q15369-1vcb: unable to check chain "K"
# 6p59-E: alignment failed to run, unable to check structure's chain
# 6p59-Z: alignment failed to run, unable to check structure's chain
# Q15369-6p59: unable to check chain "E"
# Q15369-6p59: unable to check chain "Z"
# 6r7n-Q: alignment failed to run, unable to check structure's chain
# Q15369-6r7n: unable to check chain "Q"
# 6r7f-Q: alignment failed to run, unable to check structure's chain
# Q15369-6r7f: unable to check chain "Q"
# 6r7h-Q: alignment failed to run, unable to check structure's chain
# Q15369-6r7h: unable to check chain "Q"
# 6i7r-C: alignment failed to run, unable to check structure's chain
# Q15369-6i7r: unable to check chain "C"
# 4ajy-C: alignment failed to run, unable to check structure's chain
# Q15369-4ajy: unable to check chain "C"
# 6gmr-C: alignment failed to run, unable to check structure's chain
# Q15369-6gmr: unable to check chain "C"
# 6hr2-C: alignment failed to run, unable to check structure's chain
# 6hr2-G: alignment failed to run, unable to check structure's chain
# Q15369-6hr2: unable to check chain "C"
# Q15369-6hr2: unable to check chain "G"
# 6gfx-B: alignment failed to run, unable to check structure's chain
# Q15369-6gfx: unable to check chain "B"
# 1lm8-C: alignment failed to run, unable to check structure's chain
# Q15369-1lm8: unable to check chain "C"
# 2c9w-C: alignment failed to run, unable to check structure's chain
# Q15369-2c9w: unable to check chain "C"
# 6gmn-B: alignment failed to run, unable to check structure's chain
# 6gmn-E: alignment failed to run, unable to check structure's chain
# 6gmn-H: alignment failed to run, unable to check structure's chain
# 6gmn-K: alignment failed to run, unable to check structure's chain
# Q15369-6gmn: unable to check chain "B"
# Q15369-6gmn: unable to check chain "E"
# Q15369-6gmn: unable to check chain "H"
# Q15369-6gmn: unable to check chain "K"
# 6i5n-C: alignment failed to run, unable to check structure's chain
# 6i5n-F: alignment failed to run, unable to check structure's chain
# Q15369-6i5n: unable to check chain "C"
# Q15369-6i5n: unable to check chain "F"
# 1lqb-B: alignment failed to run, unable to check structure's chain
# Q15369-1lqb: unable to check chain "B"
# 4b9k-B: alignment failed to run, unable to check structure's chain
# 4b9k-E: alignment failed to run, unable to check structure's chain
# 4b9k-H: alignment failed to run, unable to check structure's chain
# 4b9k-K: alignment failed to run, unable to check structure's chain
# Q15369-4b9k: unable to check chain "B"
# Q15369-4b9k: unable to check chain "E"
# Q15369-4b9k: unable to check chain "H"
# Q15369-4b9k: unable to check chain "K"
# 6bvb-C: alignment failed to run, unable to check structure's chain
# Q15369-6bvb: unable to check chain "C"
# 4w9f-B: alignment failed to run, unable to check structure's chain
# 4w9f-E: alignment failed to run, unable to check structure's chain
# 4w9f-H: alignment failed to run, unable to check structure's chain
# 4w9f-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9f: unable to check chain "B"
# Q15369-4w9f: unable to check chain "E"
# Q15369-4w9f: unable to check chain "H"
# Q15369-4w9f: unable to check chain "K"
# 4w9h-B: alignment failed to run, unable to check structure's chain
# 4w9h-E: alignment failed to run, unable to check structure's chain
# 4w9h-H: alignment failed to run, unable to check structure's chain
# 4w9h-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9h: unable to check chain "B"
# Q15369-4w9h: unable to check chain "E"
# Q15369-4w9h: unable to check chain "H"
# Q15369-4w9h: unable to check chain "K"
# 4w9k-B: alignment failed to run, unable to check structure's chain
# 4w9k-E: alignment failed to run, unable to check structure's chain
# 4w9k-H: alignment failed to run, unable to check structure's chain
# 4w9k-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9k: unable to check chain "B"
# Q15369-4w9k: unable to check chain "E"
# Q15369-4w9k: unable to check chain "H"
# Q15369-4w9k: unable to check chain "K"
# 5nvv-B: alignment failed to run, unable to check structure's chain
# 5nvv-E: alignment failed to run, unable to check structure's chain
# 5nvv-H: alignment failed to run, unable to check structure's chain
# 5nvv-K: alignment failed to run, unable to check structure's chain
# Q15369-5nvv: unable to check chain "B"
# Q15369-5nvv: unable to check chain "E"
# Q15369-5nvv: unable to check chain "H"
# Q15369-5nvv: unable to check chain "K"
# 5nw1-B: alignment failed to run, unable to check structure's chain
# 5nw1-E: alignment failed to run, unable to check structure's chain
# 5nw1-H: alignment failed to run, unable to check structure's chain
# 5nw1-K: alignment failed to run, unable to check structure's chain
# Q15369-5nw1: unable to check chain "B"
# Q15369-5nw1: unable to check chain "E"
# Q15369-5nw1: unable to check chain "H"
# Q15369-5nw1: unable to check chain "K"
# 4bks-B: alignment failed to run, unable to check structure's chain
# 4bks-E: alignment failed to run, unable to check structure's chain
# 4bks-H: alignment failed to run, unable to check structure's chain
# 4bks-K: alignment failed to run, unable to check structure's chain
# Q15369-4bks: unable to check chain "B"
# Q15369-4bks: unable to check chain "E"
# Q15369-4bks: unable to check chain "H"
# Q15369-4bks: unable to check chain "K"
# 4w9c-B: alignment failed to run, unable to check structure's chain
# 4w9c-E: alignment failed to run, unable to check structure's chain
# 4w9c-H: alignment failed to run, unable to check structure's chain
# 4w9c-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9c: unable to check chain "B"
# Q15369-4w9c: unable to check chain "E"
# Q15369-4w9c: unable to check chain "H"
# Q15369-4w9c: unable to check chain "K"
# 4w9d-B: alignment failed to run, unable to check structure's chain
# 4w9d-E: alignment failed to run, unable to check structure's chain
# 4w9d-H: alignment failed to run, unable to check structure's chain
# 4w9d-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9d: unable to check chain "B"
# Q15369-4w9d: unable to check chain "E"
# Q15369-4w9d: unable to check chain "H"
# Q15369-4w9d: unable to check chain "K"
# 4w9j-B: alignment failed to run, unable to check structure's chain
# 4w9j-E: alignment failed to run, unable to check structure's chain
# 4w9j-H: alignment failed to run, unable to check structure's chain
# 4w9j-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9j: unable to check chain "B"
# Q15369-4w9j: unable to check chain "E"
# Q15369-4w9j: unable to check chain "H"
# Q15369-4w9j: unable to check chain "K"
# 4w9l-B: alignment failed to run, unable to check structure's chain
# 4w9l-E: alignment failed to run, unable to check structure's chain
# 4w9l-H: alignment failed to run, unable to check structure's chain
# 4w9l-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9l: unable to check chain "B"
# Q15369-4w9l: unable to check chain "E"
# Q15369-4w9l: unable to check chain "H"
# Q15369-4w9l: unable to check chain "K"
# 5nvw-B: alignment failed to run, unable to check structure's chain
# 5nvw-E: alignment failed to run, unable to check structure's chain
# 5nvw-H: alignment failed to run, unable to check structure's chain
# 5nvw-K: alignment failed to run, unable to check structure's chain
# Q15369-5nvw: unable to check chain "B"
# Q15369-5nvw: unable to check chain "E"
# Q15369-5nvw: unable to check chain "H"
# Q15369-5nvw: unable to check chain "K"
# 5nvx-B: alignment failed to run, unable to check structure's chain
# 5nvx-E: alignment failed to run, unable to check structure's chain
# 5nvx-H: alignment failed to run, unable to check structure's chain
# 5nvx-K: alignment failed to run, unable to check structure's chain
# Q15369-5nvx: unable to check chain "B"
# Q15369-5nvx: unable to check chain "E"
# Q15369-5nvx: unable to check chain "H"
# Q15369-5nvx: unable to check chain "K"
# 5nw2-B: alignment failed to run, unable to check structure's chain
# 5nw2-E: alignment failed to run, unable to check structure's chain
# 5nw2-H: alignment failed to run, unable to check structure's chain
# 5nw2-K: alignment failed to run, unable to check structure's chain
# Q15369-5nw2: unable to check chain "B"
# Q15369-5nw2: unable to check chain "E"
# Q15369-5nw2: unable to check chain "H"
# Q15369-5nw2: unable to check chain "K"
# 6hay-C: alignment failed to run, unable to check structure's chain
# 6hay-G: alignment failed to run, unable to check structure's chain
# Q15369-6hay: unable to check chain "C"
# Q15369-6hay: unable to check chain "G"
# 5nw0-B: alignment failed to run, unable to check structure's chain
# 5nw0-E: alignment failed to run, unable to check structure's chain
# 5nw0-H: alignment failed to run, unable to check structure's chain
# 5nw0-K: alignment failed to run, unable to check structure's chain
# Q15369-5nw0: unable to check chain "B"
# Q15369-5nw0: unable to check chain "E"
# Q15369-5nw0: unable to check chain "H"
# Q15369-5nw0: unable to check chain "K"
# 6gfz-B: alignment failed to run, unable to check structure's chain
# 6gfz-E: alignment failed to run, unable to check structure's chain
# 6gfz-H: alignment failed to run, unable to check structure's chain
# 6gfz-K: alignment failed to run, unable to check structure's chain
# Q15369-6gfz: unable to check chain "B"
# Q15369-6gfz: unable to check chain "E"
# Q15369-6gfz: unable to check chain "H"
# Q15369-6gfz: unable to check chain "K"
# 4bkt-B: alignment failed to run, unable to check structure's chain
# 4bkt-E: alignment failed to run, unable to check structure's chain
# 4bkt-H: alignment failed to run, unable to check structure's chain
# 4bkt-K: alignment failed to run, unable to check structure's chain
# Q15369-4bkt: unable to check chain "B"
# Q15369-4bkt: unable to check chain "E"
# Q15369-4bkt: unable to check chain "H"
# Q15369-4bkt: unable to check chain "K"
# 6hax-C: alignment failed to run, unable to check structure's chain
# 6hax-G: alignment failed to run, unable to check structure's chain
# Q15369-6hax: unable to check chain "C"
# Q15369-6hax: unable to check chain "G"
# 3dcg-B: alignment failed to run, unable to check structure's chain
# 3dcg-D: alignment failed to run, unable to check structure's chain
# Q15369-3dcg: unable to check chain "B"
# Q15369-3dcg: unable to check chain "D"
# 4w9i-B: alignment failed to run, unable to check structure's chain
# 4w9i-E: alignment failed to run, unable to check structure's chain
# 4w9i-H: alignment failed to run, unable to check structure's chain
# 4w9i-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9i: unable to check chain "B"
# Q15369-4w9i: unable to check chain "E"
# Q15369-4w9i: unable to check chain "H"
# Q15369-4w9i: unable to check chain "K"
# 5lli-B: alignment failed to run, unable to check structure's chain
# 5lli-E: alignment failed to run, unable to check structure's chain
# 5lli-H: alignment failed to run, unable to check structure's chain
# 5lli-K: alignment failed to run, unable to check structure's chain
# Q15369-5lli: unable to check chain "B"
# Q15369-5lli: unable to check chain "E"
# Q15369-5lli: unable to check chain "H"
# Q15369-5lli: unable to check chain "K"
# 6fmj-B: alignment failed to run, unable to check structure's chain
# 6fmj-E: alignment failed to run, unable to check structure's chain
# 6fmj-H: alignment failed to run, unable to check structure's chain
# 6fmj-K: alignment failed to run, unable to check structure's chain
# Q15369-6fmj: unable to check chain "B"
# Q15369-6fmj: unable to check chain "E"
# Q15369-6fmj: unable to check chain "H"
# Q15369-6fmj: unable to check chain "K"
# 3zun-B: alignment failed to run, unable to check structure's chain
# 3zun-E: alignment failed to run, unable to check structure's chain
# 3zun-H: alignment failed to run, unable to check structure's chain
# 3zun-K: alignment failed to run, unable to check structure's chain
# Q15369-3zun: unable to check chain "B"
# Q15369-3zun: unable to check chain "E"
# Q15369-3zun: unable to check chain "H"
# Q15369-3zun: unable to check chain "K"
# 4awj-B: alignment failed to run, unable to check structure's chain
# 4awj-E: alignment failed to run, unable to check structure's chain
# 4awj-H: alignment failed to run, unable to check structure's chain
# 4awj-K: alignment failed to run, unable to check structure's chain
# Q15369-4awj: unable to check chain "B"
# Q15369-4awj: unable to check chain "E"
# Q15369-4awj: unable to check chain "H"
# Q15369-4awj: unable to check chain "K"
# 6gmx-B: alignment failed to run, unable to check structure's chain
# 6gmx-H: alignment failed to run, unable to check structure's chain
# 6gmx-K: alignment failed to run, unable to check structure's chain
# 6gmx-E: alignment failed to run, unable to check structure's chain
# Q15369-6gmx: unable to check chain "B"
# Q15369-6gmx: unable to check chain "H"
# Q15369-6gmx: unable to check chain "K"
# Q15369-6gmx: unable to check chain "E"
# 2izv-C: alignment failed to run, unable to check structure's chain
# Q15369-2izv: unable to check chain "C"
# 3zkj-B: alignment failed to run, unable to check structure's chain
# 3zkj-E: alignment failed to run, unable to check structure's chain
# Q15369-3zkj: unable to check chain "B"
# Q15369-3zkj: unable to check chain "E"
# 4w9e-B: alignment failed to run, unable to check structure's chain
# 4w9e-E: alignment failed to run, unable to check structure's chain
# 4w9e-H: alignment failed to run, unable to check structure's chain
# 4w9e-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9e: unable to check chain "B"
# Q15369-4w9e: unable to check chain "E"
# Q15369-4w9e: unable to check chain "H"
# Q15369-4w9e: unable to check chain "K"
# 3ztc-B: alignment failed to run, unable to check structure's chain
# 3ztc-E: alignment failed to run, unable to check structure's chain
# 3ztc-H: alignment failed to run, unable to check structure's chain
# 3ztc-K: alignment failed to run, unable to check structure's chain
# Q15369-3ztc: unable to check chain "B"
# Q15369-3ztc: unable to check chain "E"
# Q15369-3ztc: unable to check chain "H"
# Q15369-3ztc: unable to check chain "K"
# 6i4x-C: alignment failed to run, unable to check structure's chain
# Q15369-6i4x: unable to check chain "C"
# 4w9g-B: alignment failed to run, unable to check structure's chain
# 4w9g-E: alignment failed to run, unable to check structure's chain
# 4w9g-H: alignment failed to run, unable to check structure's chain
# 4w9g-K: alignment failed to run, unable to check structure's chain
# Q15369-4w9g: unable to check chain "B"
# Q15369-4w9g: unable to check chain "E"
# Q15369-4w9g: unable to check chain "H"
# Q15369-4w9g: unable to check chain "K"
# 5nvz-B: alignment failed to run, unable to check structure's chain
# 5nvz-E: alignment failed to run, unable to check structure's chain
# 5nvz-H: alignment failed to run, unable to check structure's chain
# 5nvz-K: alignment failed to run, unable to check structure's chain
# Q15369-5nvz: unable to check chain "B"
# Q15369-5nvz: unable to check chain "E"
# Q15369-5nvz: unable to check chain "H"
# Q15369-5nvz: unable to check chain "K"
# 5t35-C: alignment failed to run, unable to check structure's chain
# 5t35-G: alignment failed to run, unable to check structure's chain
# Q15369-5t35: unable to check chain "C"
# Q15369-5t35: unable to check chain "G"
# 6gfy-B: alignment failed to run, unable to check structure's chain
# 6gfy-E: alignment failed to run, unable to check structure's chain
# 6gfy-H: alignment failed to run, unable to check structure's chain
# 6gfy-K: alignment failed to run, unable to check structure's chain
# Q15369-6gfy: unable to check chain "B"
# Q15369-6gfy: unable to check chain "E"
# Q15369-6gfy: unable to check chain "H"
# Q15369-6gfy: unable to check chain "K"
# 6fmk-B: alignment failed to run, unable to check structure's chain
# 6fmk-E: alignment failed to run, unable to check structure's chain
# 6fmk-H: alignment failed to run, unable to check structure's chain
# 6fmk-K: alignment failed to run, unable to check structure's chain
# Q15369-6fmk: unable to check chain "B"
# Q15369-6fmk: unable to check chain "E"
# Q15369-6fmk: unable to check chain "H"
# Q15369-6fmk: unable to check chain "K"
# 6gmq-H: alignment failed to run, unable to check structure's chain
# 6gmq-K: alignment failed to run, unable to check structure's chain
# 6gmq-B: alignment failed to run, unable to check structure's chain
# 6gmq-E: alignment failed to run, unable to check structure's chain
# Q15369-6gmq: unable to check chain "H"
# Q15369-6gmq: unable to check chain "K"
# Q15369-6gmq: unable to check chain "B"
# Q15369-6gmq: unable to check chain "E"
# 3ztd-B: alignment failed to run, unable to check structure's chain
# 3ztd-E: alignment failed to run, unable to check structure's chain
# 3ztd-H: alignment failed to run, unable to check structure's chain
# 3ztd-K: alignment failed to run, unable to check structure's chain
# Q15369-3ztd: unable to check chain "B"
# Q15369-3ztd: unable to check chain "E"
# Q15369-3ztd: unable to check chain "H"
# Q15369-3ztd: unable to check chain "K"
# 3zrf-B: alignment failed to run, unable to check structure's chain
# 3zrf-E: alignment failed to run, unable to check structure's chain
# 3zrf-H: alignment failed to run, unable to check structure's chain
# 3zrf-K: alignment failed to run, unable to check structure's chain
# Q15369-3zrf: unable to check chain "B"
# Q15369-3zrf: unable to check chain "E"
# Q15369-3zrf: unable to check chain "H"
# Q15369-3zrf: unable to check chain "K"
# 6fmi-B: alignment failed to run, unable to check structure's chain
# 6fmi-E: alignment failed to run, unable to check structure's chain
# Q15369-6fmi: unable to check chain "B"
# Q15369-6fmi: unable to check chain "E"
# 6i5j-C: alignment failed to run, unable to check structure's chain
# 6i5j-F: alignment failed to run, unable to check structure's chain
# Q15369-6i5j: unable to check chain "C"
# Q15369-6i5j: unable to check chain "F"
# 3zng-B: alignment failed to run, unable to check structure's chain
# 3zng-E: alignment failed to run, unable to check structure's chain
# Q15369-3zng: unable to check chain "B"
# Q15369-3zng: unable to check chain "E"
# 3zrc-B: alignment failed to run, unable to check structure's chain
# 3zrc-E: alignment failed to run, unable to check structure's chain
# 3zrc-H: alignment failed to run, unable to check structure's chain
# 3zrc-K: alignment failed to run, unable to check structure's chain
# Q15369-3zrc: unable to check chain "B"
# Q15369-3zrc: unable to check chain "E"
# Q15369-3zrc: unable to check chain "H"
# Q15369-3zrc: unable to check chain "K"
# 5bo4-C: alignment failed to run, unable to check structure's chain
# 5bo4-F: alignment failed to run, unable to check structure's chain
# 5bo4-I: alignment failed to run, unable to check structure's chain
# 5bo4-L: alignment failed to run, unable to check structure's chain
# 5bo4-O: alignment failed to run, unable to check structure's chain
# 5bo4-R: alignment failed to run, unable to check structure's chain
# Q15369-5bo4: unable to check chain "C"
# Q15369-5bo4: unable to check chain "F"
# Q15369-5bo4: unable to check chain "I"
# Q15369-5bo4: unable to check chain "L"
# Q15369-5bo4: unable to check chain "O"
# Q15369-5bo4: unable to check chain "R"
# 5nvy-B: alignment failed to run, unable to check structure's chain
# 5nvy-E: alignment failed to run, unable to check structure's chain
# 5nvy-H: alignment failed to run, unable to check structure's chain
# 5nvy-K: alignment failed to run, unable to check structure's chain
# Q15369-5nvy: unable to check chain "B"
# Q15369-5nvy: unable to check chain "E"
# Q15369-5nvy: unable to check chain "H"
# Q15369-5nvy: unable to check chain "K"
# 6c5x-C: alignment failed to run, unable to check structure's chain
# 6c5x-F: alignment failed to run, unable to check structure's chain
# Q15369-6c5x: unable to check chain "C"
# Q15369-6c5x: unable to check chain "F"
# 4wqo-C: alignment failed to run, unable to check structure's chain
# Q15369-4wqo: unable to check chain "C"
# 4n9f-5: alignment failed to run, unable to check structure's chain
# 4n9f-B: alignment failed to run, unable to check structure's chain
# 4n9f-E: alignment failed to run, unable to check structure's chain
# 4n9f-K: alignment failed to run, unable to check structure's chain
# 4n9f-Q: alignment failed to run, unable to check structure's chain
# 4n9f-T: alignment failed to run, unable to check structure's chain
# 4n9f-Y: alignment failed to run, unable to check structure's chain
# 4n9f-Z: alignment failed to run, unable to check structure's chain
# 4n9f-h: alignment failed to run, unable to check structure's chain
# 4n9f-n: alignment failed to run, unable to check structure's chain
# 4n9f-t: alignment failed to run, unable to check structure's chain
# 4n9f-z: alignment failed to run, unable to check structure's chain
# Q15369-4n9f: unable to check chain "5"
# Q15369-4n9f: unable to check chain "B"
# Q15369-4n9f: unable to check chain "E"
# Q15369-4n9f: unable to check chain "K"
# Q15369-4n9f: unable to check chain "Q"
# Q15369-4n9f: unable to check chain "T"
# Q15369-4n9f: unable to check chain "Y"
# Q15369-4n9f: unable to check chain "Z"
# Q15369-4n9f: unable to check chain "h"
# Q15369-4n9f: unable to check chain "n"
# Q15369-4n9f: unable to check chain "t"
# Q15369-4n9f: unable to check chain "z"
# 6sis-C: alignment failed to run, unable to check structure's chain
# 6sis-G: alignment failed to run, unable to check structure's chain
# Q15369-6sis: unable to check chain "C"
# Q15369-6sis: unable to check chain "G"
# 5n4w-C: alignment failed to run, unable to check structure's chain
# Q15369-5n4w: unable to check chain "C"
# 4b95-B: alignment failed to run, unable to check structure's chain
# 4b95-E: alignment failed to run, unable to check structure's chain
# 4b95-H: alignment failed to run, unable to check structure's chain
# 4b95-K: alignment failed to run, unable to check structure's chain
# Q15369-4b95: unable to check chain "B"
# Q15369-4b95: unable to check chain "E"
# Q15369-4b95: unable to check chain "H"
# Q15369-4b95: unable to check chain "K"
# 2ma9-C: alignment failed to run, unable to check structure's chain
# Q15369-2ma9: unable to check chain "C"
# ELOC_HUMAN: no structures meet quality checks
# 2cbz-A: alignment failed to run, unable to check structure's chain
# P33527-2cbz: unable to check chain "A"
# MRP1_HUMAN: no structures meet quality checks
# 4jol-F: alignment failed to run, unable to check structure's chain
# 4jol-H: alignment failed to run, unable to check structure's chain
# Q99081-4jol: unable to check chain "F"
# Q99081-4jol: unable to check chain "H"
# HTF4_HUMAN: no structures meet quality checks
# 5h78-A: alignment failed to run, unable to check structure's chain
# 5h78-B: alignment failed to run, unable to check structure's chain
# P13861-5h78: unable to check chain "A"
# P13861-5h78: unable to check chain "B"
# 2kyg-B: alignment failed to run, unable to check structure's chain
# P13861-2kyg: unable to check chain "B"
# 4zp3-B: alignment failed to run, unable to check structure's chain
# 4zp3-D: alignment failed to run, unable to check structure's chain
# 4zp3-F: alignment failed to run, unable to check structure's chain
# 4zp3-H: alignment failed to run, unable to check structure's chain
# 4zp3-J: alignment failed to run, unable to check structure's chain
# 4zp3-L: alignment failed to run, unable to check structure's chain
# P13861-4zp3: unable to check chain "B"
# P13861-4zp3: unable to check chain "D"
# P13861-4zp3: unable to check chain "F"
# P13861-4zp3: unable to check chain "H"
# P13861-4zp3: unable to check chain "J"
# P13861-4zp3: unable to check chain "L"
# 2izx-B: alignment failed to run, unable to check structure's chain
# P13861-2izx: unable to check chain "B"
# 5xby-A: alignment failed to run, unable to check structure's chain
# 5xby-B: alignment failed to run, unable to check structure's chain
# 5xby-C: alignment failed to run, unable to check structure's chain
# 5xby-D: alignment failed to run, unable to check structure's chain
# P13861-5xby: unable to check chain "A"
# P13861-5xby: unable to check chain "B"
# P13861-5xby: unable to check chain "C"
# P13861-5xby: unable to check chain "D"
# 5h77-A: alignment failed to run, unable to check structure's chain
# 5h77-B: alignment failed to run, unable to check structure's chain
# 5h77-C: alignment failed to run, unable to check structure's chain
# 5h77-D: alignment failed to run, unable to check structure's chain
# 5h77-E: alignment failed to run, unable to check structure's chain
# 5h77-F: alignment failed to run, unable to check structure's chain
# 5h77-G: alignment failed to run, unable to check structure's chain
# 5h77-H: alignment failed to run, unable to check structure's chain
# 5h77-I: alignment failed to run, unable to check structure's chain
# 5h77-J: alignment failed to run, unable to check structure's chain
# 5h77-K: alignment failed to run, unable to check structure's chain
# 5h77-L: alignment failed to run, unable to check structure's chain
# P13861-5h77: unable to check chain "A"
# P13861-5h77: unable to check chain "B"
# P13861-5h77: unable to check chain "C"
# P13861-5h77: unable to check chain "D"
# P13861-5h77: unable to check chain "E"
# P13861-5h77: unable to check chain "F"
# P13861-5h77: unable to check chain "G"
# P13861-5h77: unable to check chain "H"
# P13861-5h77: unable to check chain "I"
# P13861-5h77: unable to check chain "J"
# P13861-5h77: unable to check chain "K"
# P13861-5h77: unable to check chain "L"
# KAP2_HUMAN: no structures meet quality checks
# 1wfq-A: alignment failed to run, unable to check structure's chain
# O75534-1wfq: unable to check chain "A"
# 2yty-A: alignment failed to run, unable to check structure's chain
# O75534-2yty: unable to check chain "A"
# CSDE1_HUMAN: no structures meet quality checks
# 6qpi-A: alignment failed to run, unable to check structure's chain
# 6qpi-B: alignment failed to run, unable to check structure's chain
# Q4KMQ2-6qpi: unable to check chain "A"
# Q4KMQ2-6qpi: unable to check chain "B"
# 6qpc-A: alignment failed to run, unable to check structure's chain
# 6qpc-B: alignment failed to run, unable to check structure's chain
# Q4KMQ2-6qpc: unable to check chain "A"
# Q4KMQ2-6qpc: unable to check chain "B"
# 6qpb-A: alignment failed to run, unable to check structure's chain
# 6qpb-B: alignment failed to run, unable to check structure's chain
# Q4KMQ2-6qpb: unable to check chain "A"
# Q4KMQ2-6qpb: unable to check chain "B"
# 6qp6-A: alignment failed to run, unable to check structure's chain
# 6qp6-B: alignment failed to run, unable to check structure's chain
# Q4KMQ2-6qp6: unable to check chain "A"
# Q4KMQ2-6qp6: unable to check chain "B"
# 6p49-A: alignment failed to run, unable to check structure's chain
# 6p49-B: alignment failed to run, unable to check structure's chain
# Q4KMQ2-6p49: unable to check chain "A"
# Q4KMQ2-6p49: unable to check chain "B"
# 6p48-A: alignment failed to run, unable to check structure's chain
# 6p48-B: alignment failed to run, unable to check structure's chain
# Q4KMQ2-6p48: unable to check chain "A"
# Q4KMQ2-6p48: unable to check chain "B"
# ...
# 4xue-A: alignment failed to run, unable to check structure's chain
# 4xue-B: alignment failed to run, unable to check structure's chain
# P21964-4xue: unable to check chain "A"
# P21964-4xue: unable to check chain "B"
# 3a7e-A: alignment failed to run, unable to check structure's chain
# P21964-3a7e: unable to check chain "A"
# COMT_HUMAN: no structures meet quality checks
# 4cq1-A: alignment failed to run, unable to check structure's chain
# 4cq1-C: alignment failed to run, unable to check structure's chain
# 4cq1-E: alignment failed to run, unable to check structure's chain
# 4cq1-G: alignment failed to run, unable to check structure's chain
# Q9UKA9-4cq1: unable to check chain "A"
# Q9UKA9-4cq1: unable to check chain "C"
# Q9UKA9-4cq1: unable to check chain "E"
# Q9UKA9-4cq1: unable to check chain "G"
# 2cq1-A: alignment failed to run, unable to check structure's chain
# Q9UKA9-2cq1: unable to check chain "A"
# PTBP2_HUMAN: no structures meet quality checks
# 6owt-A: alignment failed to run, unable to check structure's chain
# O94973-6owt: unable to check chain "A"
# AP2A2_HUMAN: no structures meet quality checks
# 6v6b-C: alignment failed to run, unable to check structure's chain
# Q9BSJ2-6v6b: unable to check chain "C"
# 6v6s: structure file could not be downloaded in pdb format
# GCP2_HUMAN: no structures meet quality checks
# 2jv5-A: alignment failed to run, unable to check structure's chain
# Q9NQC3-2jv5: unable to check chain "A"
# RTN4_HUMAN: no structures meet quality checks
# 6g8t-A: alignment failed to run, unable to check structure's chain
# Q9BQQ3-6g8t: unable to check chain "A"
# 6g8w-B: alignment failed to run, unable to check structure's chain
# Q9BQQ3-6g8w: unable to check chain "B"
# GORS1_HUMAN: no structures meet quality checks
# 2wjy-A: alignment failed to run, unable to check structure's chain
# Q92900-2wjy: unable to check chain "A"
# 2wjv-A: alignment failed to run, unable to check structure's chain
# 2wjv-B: alignment failed to run, unable to check structure's chain
# Q92900-2wjv: unable to check chain "A"
# Q92900-2wjv: unable to check chain "B"
# 2xzo-A: alignment failed to run, unable to check structure's chain
# Q92900-2xzo: unable to check chain "A"
# 2gk6-B: alignment failed to run, unable to check structure's chain
# Q92900-2gk6: unable to check chain "B"
# 2xzp-A: alignment failed to run, unable to check structure's chain
# Q92900-2xzp: unable to check chain "A"
# 2iyk-A: alignment failed to run, unable to check structure's chain
# Q92900-2iyk: unable to check chain "A"
# RENT1_HUMAN: no structures meet quality checks
# 5nvl-D: alignment failed to run, unable to check structure's chain
# Q6Y7W6-5nvl: unable to check chain "D"
# 5nvm-D: alignment failed to run, unable to check structure's chain
# Q6Y7W6-5nvm: unable to check chain "D"
# GGYF2_HUMAN: no structures meet quality checks
# 4wxx-A: alignment failed to run, unable to check structure's chain
# 4wxx-B: alignment failed to run, unable to check structure's chain
# P26358-4wxx: unable to check chain "A"
# P26358-4wxx: unable to check chain "B"
# 4yoc-A: alignment failed to run, unable to check structure's chain
# P26358-4yoc: unable to check chain "A"
# 5wvo-C: alignment failed to run, unable to check structure's chain
# P26358-5wvo: unable to check chain "C"
# 3epz-B: alignment failed to run, unable to check structure's chain
# P26358-3epz: unable to check chain "B"
# 4z96-C: alignment failed to run, unable to check structure's chain
# P26358-4z96: unable to check chain "C"
# 6k3a-B: alignment failed to run, unable to check structure's chain
# 6k3a-F: alignment failed to run, unable to check structure's chain
# P26358-6k3a: unable to check chain "B"
# P26358-6k3a: unable to check chain "F"
# DNMT1_HUMAN: no structures meet quality checks
# 5xwm-A: alignment failed to run, unable to check structure's chain
# 5xwm-B: alignment failed to run, unable to check structure's chain
# 5xwm-C: alignment failed to run, unable to check structure's chain
# 5xwm-D: alignment failed to run, unable to check structure's chain
# Q9BS26-5xwm: unable to check chain "A"
# Q9BS26-5xwm: unable to check chain "B"
# Q9BS26-5xwm: unable to check chain "C"
# Q9BS26-5xwm: unable to check chain "D"
# 2r2j-A: alignment failed to run, unable to check structure's chain
# Q9BS26-2r2j: unable to check chain "A"
# 5hqp-C: alignment failed to run, unable to check structure's chain
# 5hqp-D: alignment failed to run, unable to check structure's chain
# Q9BS26-5hqp: unable to check chain "C"
# Q9BS26-5hqp: unable to check chain "D"
# 5gu6-A: alignment failed to run, unable to check structure's chain
# Q9BS26-5gu6: unable to check chain "A"
# 5gu7-C: alignment failed to run, unable to check structure's chain
# Q9BS26-5gu7: unable to check chain "C"
# ERP44_HUMAN: no structures meet quality checks
# 6vqh-c: alignment failed to run, unable to check structure's chain
# Q15904-6vqh: unable to check chain "c"
# 6vqg-c: alignment failed to run, unable to check structure's chain
# Q15904-6vqg: unable to check chain "c"
# 6vqc-c: alignment failed to run, unable to check structure's chain
# Q15904-6vqc: unable to check chain "c"
# 6vq8-c: alignment failed to run, unable to check structure's chain
# Q15904-6vq8: unable to check chain "c"
# 6vq7-c: alignment failed to run, unable to check structure's chain
# Q15904-6vq7: unable to check chain "c"
# 6vq6-c: alignment failed to run, unable to check structure's chain
# Q15904-6vq6: unable to check chain "c"
# VAS1_HUMAN: no structures meet quality checks
# 2cm0-A: alignment failed to run, unable to check structure's chain
# Q96IV0-2cm0: unable to check chain "A"
# NGLY1_HUMAN: no structures meet quality checks
# 1bda-B: alignment failed to run, unable to check structure's chain
# P00750-1bda: unable to check chain "B"
# 1a5h-A: alignment failed to run, unable to check structure's chain
# 1a5h-C: alignment failed to run, unable to check structure's chain
# P00750-1a5h: unable to check chain "A"
# P00750-1a5h: unable to check chain "C"
# 5brr-E: alignment failed to run, unable to check structure's chain
# P00750-5brr: unable to check chain "E"
# 1tpg-A: alignment failed to run, unable to check structure's chain
# P00750-1tpg: unable to check chain "A"
# 1tpk-A: alignment failed to run, unable to check structure's chain
# 1tpk-C: alignment failed to run, unable to check structure's chain
# P00750-1tpk: unable to check chain "A"
# P00750-1tpk: unable to check chain "C"
# 1pml-B: alignment failed to run, unable to check structure's chain
# P00750-1pml: unable to check chain "B"
# 1tpm-A: alignment failed to run, unable to check structure's chain
# P00750-1tpm: unable to check chain "A"
# TPA_HUMAN: no structures meet quality checks
# 4zdl-A: alignment failed to run, unable to check structure's chain
# 4zdl-B: alignment failed to run, unable to check structure's chain
# Q9HD40-4zdl: unable to check chain "A"
# Q9HD40-4zdl: unable to check chain "B"
# 4zdo-A: alignment failed to run, unable to check structure's chain
# 4zdo-B: alignment failed to run, unable to check structure's chain
# 4zdo-C: alignment failed to run, unable to check structure's chain
# 4zdo-D: alignment failed to run, unable to check structure's chain
# Q9HD40-4zdo: unable to check chain "A"
# Q9HD40-4zdo: unable to check chain "B"
# Q9HD40-4zdo: unable to check chain "C"
# Q9HD40-4zdo: unable to check chain "D"
# 4zdp-A: alignment failed to run, unable to check structure's chain
# 4zdp-B: alignment failed to run, unable to check structure's chain
# 4zdp-C: alignment failed to run, unable to check structure's chain
# 4zdp-D: alignment failed to run, unable to check structure's chain
# Q9HD40-4zdp: unable to check chain "A"
# Q9HD40-4zdp: unable to check chain "B"
# Q9HD40-4zdp: unable to check chain "C"
# Q9HD40-4zdp: unable to check chain "D"
# 3hl2-A: alignment failed to run, unable to check structure's chain
# 3hl2-B: alignment failed to run, unable to check structure's chain
# 3hl2-C: alignment failed to run, unable to check structure's chain
# 3hl2-D: alignment failed to run, unable to check structure's chain
# Q9HD40-3hl2: unable to check chain "A"
# Q9HD40-3hl2: unable to check chain "B"
# Q9HD40-3hl2: unable to check chain "C"
# Q9HD40-3hl2: unable to check chain "D"
# SPCS_HUMAN: no structures meet quality checks
# 1gxr-B: alignment failed to run, unable to check structure's chain
# Q04724-1gxr: unable to check chain "B"
# 2ce8-B: alignment failed to run, unable to check structure's chain
# 2ce8-D: alignment failed to run, unable to check structure's chain
# Q04724-2ce8: unable to check chain "B"
# Q04724-2ce8: unable to check chain "D"
# 2ce9-B: alignment failed to run, unable to check structure's chain
# 2ce9-D: alignment failed to run, unable to check structure's chain
# Q04724-2ce9: unable to check chain "B"
# Q04724-2ce9: unable to check chain "D"
# 5mwj-B: alignment failed to run, unable to check structure's chain
# Q04724-5mwj: unable to check chain "B"
# 4om2-B: alignment failed to run, unable to check structure's chain
# 4om2-D: alignment failed to run, unable to check structure's chain
# Q04724-4om2: unable to check chain "B"
# Q04724-4om2: unable to check chain "D"
# 4om3-B: alignment failed to run, unable to check structure's chain
# 4om3-D: alignment failed to run, unable to check structure's chain
# Q04724-4om3: unable to check chain "B"
# Q04724-4om3: unable to check chain "D"
# TLE1_HUMAN: no structures meet quality checks
# 2bsk-A: alignment failed to run, unable to check structure's chain
# 2bsk-C: alignment failed to run, unable to check structure's chain
# 2bsk-E: alignment failed to run, unable to check structure's chain
# Q9Y5J7-2bsk: unable to check chain "A"
# Q9Y5J7-2bsk: unable to check chain "C"
# Q9Y5J7-2bsk: unable to check chain "E"
# TIM9_HUMAN: no structures meet quality checks
# 5lsu-B: alignment failed to run, unable to check structure's chain
# O96028-5lsu: unable to check chain "B"
# 5vc8-B: alignment failed to run, unable to check structure's chain
# O96028-5vc8: unable to check chain "B"
# 6ue6-B: alignment failed to run, unable to check structure's chain
# 6ue6-D: alignment failed to run, unable to check structure's chain
# 6ue6-F: alignment failed to run, unable to check structure's chain
# 6ue6-H: alignment failed to run, unable to check structure's chain
# O96028-6ue6: unable to check chain "B"
# O96028-6ue6: unable to check chain "D"
# O96028-6ue6: unable to check chain "F"
# O96028-6ue6: unable to check chain "H"
# NSD2_HUMAN: no structures meet quality checks
# 2gwf-B: alignment failed to run, unable to check structure's chain
# 2gwf-F: alignment failed to run, unable to check structure's chain
# Q9H4P4-2gwf: unable to check chain "B"
# Q9H4P4-2gwf: unable to check chain "F"
# RNF41_HUMAN: no structures meet quality checks
# 1x3s-A: alignment failed to run, unable to check structure's chain
# Q9NP72-1x3s: unable to check chain "A"
# RAB18_HUMAN: no structures meet quality checks
# 2bsk-B: alignment failed to run, unable to check structure's chain
# 2bsk-D: alignment failed to run, unable to check structure's chain
# 2bsk-F: alignment failed to run, unable to check structure's chain
# P62072-2bsk: unable to check chain "B"
# P62072-2bsk: unable to check chain "D"
# P62072-2bsk: unable to check chain "F"
# TIM10_HUMAN: no structures meet quality checks
# 2nn6-D: alignment failed to run, unable to check structure's chain
# Q9NQT4-2nn6: unable to check chain "D"
# 6d6q-D: alignment failed to run, unable to check structure's chain
# Q9NQT4-6d6q: unable to check chain "D"
# 6d6r-D: alignment failed to run, unable to check structure's chain
# Q9NQT4-6d6r: unable to check chain "D"
# 6h25-D: alignment failed to run, unable to check structure's chain
# Q9NQT4-6h25: unable to check chain "D"
# EXOS5_HUMAN: no structures meet quality checks
# 4dxt-A: alignment failed to run, unable to check structure's chain
# Q9UH99-4dxt: unable to check chain "A"
# 4dxs-A: alignment failed to run, unable to check structure's chain
# Q9UH99-4dxs: unable to check chain "A"
# SUN2_HUMAN: no structures meet quality checks
# 4ndn-E: alignment failed to run, unable to check structure's chain
# 4ndn-F: alignment failed to run, unable to check structure's chain
# Q9NZL9-4ndn: unable to check chain "E"
# Q9NZL9-4ndn: unable to check chain "F"
# 4ktt-E: alignment failed to run, unable to check structure's chain
# 4ktt-F: alignment failed to run, unable to check structure's chain
# Q9NZL9-4ktt: unable to check chain "E"
# Q9NZL9-4ktt: unable to check chain "F"
# 4ktv-E: alignment failed to run, unable to check structure's chain
# 4ktv-F: alignment failed to run, unable to check structure's chain
# Q9NZL9-4ktv: unable to check chain "E"
# Q9NZL9-4ktv: unable to check chain "F"
# 2ydy-A: alignment failed to run, unable to check structure's chain
# Q9NZL9-2ydy: unable to check chain "A"
# 2ydx-A: alignment failed to run, unable to check structure's chain
# 2ydx-B: alignment failed to run, unable to check structure's chain
# 2ydx-C: alignment failed to run, unable to check structure's chain
# 2ydx-D: alignment failed to run, unable to check structure's chain
# 2ydx-E: alignment failed to run, unable to check structure's chain
# Q9NZL9-2ydx: unable to check chain "A"
# Q9NZL9-2ydx: unable to check chain "B"
# Q9NZL9-2ydx: unable to check chain "C"
# Q9NZL9-2ydx: unable to check chain "D"
# Q9NZL9-2ydx: unable to check chain "E"
# MAT2B_HUMAN: no structures meet quality checks
# 5kiw-C: alignment failed to run, unable to check structure's chain
# Q9BQE4-5kiw: unable to check chain "C"
# 5kiu-A: alignment failed to run, unable to check structure's chain
# Q9BQE4-5kiu: unable to check chain "A"
# 6do4-C: alignment failed to run, unable to check structure's chain
# Q9BQE4-6do4: unable to check chain "C"
# SELS_HUMAN: no structures meet quality checks
# 1jid-A: alignment failed to run, unable to check structure's chain
# P09132-1jid: unable to check chain "A"
# 4p3e-B: alignment failed to run, unable to check structure's chain
# P09132-4p3e: unable to check chain "B"
# 3ktv-B: alignment failed to run, unable to check structure's chain
# 3ktv-D: alignment failed to run, unable to check structure's chain
# P09132-3ktv: unable to check chain "B"
# P09132-3ktv: unable to check chain "D"
# 5m73-B: alignment failed to run, unable to check structure's chain
# 5m73-F: alignment failed to run, unable to check structure's chain
# P09132-5m73: unable to check chain "B"
# P09132-5m73: unable to check chain "F"
# 1mfq-B: alignment failed to run, unable to check structure's chain
# P09132-1mfq: unable to check chain "B"
# 2j37-B: alignment failed to run, unable to check structure's chain
# P09132-2j37: unable to check chain "B"
# 1ry1-B: alignment failed to run, unable to check structure's chain
# P09132-1ry1: unable to check chain "B"
# SRP19_HUMAN: no structures meet quality checks
# 4x6q-B: alignment failed to run, unable to check structure's chain
# P31323-4x6q: unable to check chain "B"
# 4wbb-A: alignment failed to run, unable to check structure's chain
# P31323-4wbb: unable to check chain "A"
# 3tnq-A: alignment failed to run, unable to check structure's chain
# P31323-3tnq: unable to check chain "A"
# 3tnp-B: alignment failed to run, unable to check structure's chain
# 3tnp-E: alignment failed to run, unable to check structure's chain
# P31323-3tnp: unable to check chain "B"
# P31323-3tnp: unable to check chain "E"
# 4jva-A: alignment failed to run, unable to check structure's chain
# P31323-4jva: unable to check chain "A"
# 1cx4-A: alignment failed to run, unable to check structure's chain
# P31323-1cx4: unable to check chain "A"
# KAP3_HUMAN: no structures meet quality checks
# 4drz-A: alignment failed to run, unable to check structure's chain
# P61106-4drz: unable to check chain "A"
# 1z0f-A: alignment failed to run, unable to check structure's chain
# P61106-1z0f: unable to check chain "A"
# 4d0g-A: alignment failed to run, unable to check structure's chain
# P61106-4d0g: unable to check chain "A"
# RAB14_HUMAN: no structures meet quality checks
# 1l9x-A: alignment failed to run, unable to check structure's chain
# 1l9x-B: alignment failed to run, unable to check structure's chain
# 1l9x-C: alignment failed to run, unable to check structure's chain
# 1l9x-D: alignment failed to run, unable to check structure's chain
# Q92820-1l9x: unable to check chain "A"
# Q92820-1l9x: unable to check chain "B"
# Q92820-1l9x: unable to check chain "C"
# Q92820-1l9x: unable to check chain "D"
# GGH_HUMAN: no structures meet quality checks

# %%
g.missing_pdb_structures
# Out:
# ['EMC1_HUMAN',
#  'TRI59_HUMAN',
#  'GBG5_HUMAN',
#  'FXL12_HUMAN',
#  'AKAP9_HUMAN',
#  'HYOU1_HUMAN',
#  'CLIP4_HUMAN',
#  'GCC1_HUMAN',
#  'NDUF2_HUMAN',
#  'MYCB2_HUMAN',
#  'CE112_HUMAN',
#  'ALG8_HUMAN',
#  'MPPA_HUMAN',
#  'ACSL3_HUMAN',
#  'PIGO_HUMAN',
#  'CLCC1_HUMAN',
#  'CNTRL_HUMAN',
#  'SBNO1_HUMAN',
#  'FBLN5_HUMAN',
#  'INHBE_HUMAN',
#  'DDX21_HUMAN',
#  'D19L1_HUMAN',
#  'ZN503_HUMAN',
#  'STC2_HUMAN',
#  'TYSD1_HUMAN',
#  'PLOD2_HUMAN',
#  'AKP8L_HUMAN',
#  'AAR2_HUMAN',
#  'NAT14_HUMAN',
#  'TMED5_HUMAN',
#  'CK5P2_HUMAN',
#  'REEP5_HUMAN',
#  'NEUR1_HUMAN',
#  'UBP2L_HUMAN',
#  'S27A2_HUMAN',
#  'ODC_HUMAN',
#  'ATP5L_HUMAN',
#  'GT251_HUMAN',
#  'GOGA7_HUMAN',
#  'TM39B_HUMAN',
#  'MTCH1_HUMAN',
#  'CEP68_HUMAN',
#  'UBAP2_HUMAN',
#  'CA050_HUMAN',
#  'PCSK6_HUMAN',
#  'ERLEC_HUMAN',
#  'DCAF7_HUMAN',
#  'ZNT6_HUMAN',
#  'ALG5_HUMAN',
#  'CO6A1_HUMAN',
#  'CTL2_HUMAN',
#  'ATE1_HUMAN',
#  'TOM70_HUMAN',
#  'ERMP1_HUMAN',
#  'FKB10_HUMAN',
#  'FACR2_HUMAN',
#  'TM2D3_HUMAN',
#  'PIGS_HUMAN',
#  'TIM14_HUMAN',
#  'SCRB1_HUMAN',
#  'VKGC_HUMAN',
#  'PUSL1_HUMAN',
#  'Z3H7A_HUMAN',
#  'DPH5_HUMAN',
#  'SYTM_HUMAN',
#  'WFS1_HUMAN',
#  'NUP88_HUMAN',
#  'SMOC1_HUMAN',
#  'STOM_HUMAN',
#  'STML2_HUMAN',
#  'DJC11_HUMAN',
#  'UBP54_HUMAN',
#  'TLE5_HUMAN',
#  'CE350_HUMAN',
#  'JKIP1_HUMAN',
#  'MFGM_HUMAN',
#  'GOGA3_HUMAN',
#  'CTRO_HUMAN',
#  'TIM8B_HUMAN',
#  'PLD3_HUMAN',
#  'COQ8B_HUMAN',
#  'ALG11_HUMAN',
#  'PKHF2_HUMAN',
#  'PKHA5_HUMAN',
#  'AT133_HUMAN',
#  'TIM29_HUMAN',
#  'FKB15_HUMAN',
#  'VPS11_HUMAN',
#  'ERO1B_HUMAN',
#  'GPAA1_HUMAN',
#  'YIF1A_HUMAN',
#  'NPTX1_HUMAN',
#  'PABP4_HUMAN',
#  'CP250_HUMAN',
#  'ACAD9_HUMAN',
#  'G3BP2_HUMAN',
#  'HEAT3_HUMAN',
#  'RADI_HUMAN',
#  'NFIP2_HUMAN',
#  'RB6I2_HUMAN',
#  'RBM41_HUMAN',
#  'PO210_HUMAN',
#  'F162A_HUMAN',
#  'DDX10_HUMAN',
#  'AR6P6_HUMAN',
#  'FXRD2_HUMAN',
#  'PCNT_HUMAN',
#  'CCD86_HUMAN',
#  'TLE3_HUMAN',
#  'CRTC3_HUMAN',
#  'INT4_HUMAN',
#  'LYOX_HUMAN',
#  'DCAKD_HUMAN',
#  'UGGG2_HUMAN',
#  'BZW2_HUMAN',
#  'MOV10_HUMAN',
#  'REEP6_HUMAN',
#  'AKAP8_HUMAN',
#  'CHSS2_HUMAN',
#  'WASC4_HUMAN',
#  'GRPE1_HUMAN',
#  'GOGB1_HUMAN',
#  'EDEM3_HUMAN',
#  'TBKB1_HUMAN',
#  'IF4H_HUMAN',
#  'SCPDL_HUMAN',
#  'SDF2_HUMAN',
#  'PDZ11_HUMAN',
#  'NOL10_HUMAN',
#  'FAKD5_HUMAN',
#  'PLGT2_HUMAN',
#  'AP3B1_HUMAN',
#  'PLGT3_HUMAN',
#  'SGMR2_HUMAN',
#  'T10B_HUMAN',
#  'ZY11B_HUMAN',
#  'NINL_HUMAN',
#  'SYNM_HUMAN',
#  'UBXN8_HUMAN',
#  'MDN1_HUMAN',
#  'ZN318_HUMAN',
#  'ADAM9_HUMAN',
#  'MA7D1_HUMAN',
#  'SAAL1_HUMAN',
#  'MPPB_HUMAN',
#  'GHITM_HUMAN',
#  'ZNT9_HUMAN',
#  'RBM28_HUMAN',
#  'SCAP_HUMAN',
#  'CHM2A_HUMAN',
#  'MPP10_HUMAN',
#  'QSOX2_HUMAN',
#  'CHPF2_HUMAN',
#  'NGDN_HUMAN',
#  'HOOK1_HUMAN',
#  'ECSIT_HUMAN',
#  'CIA30_HUMAN',
#  'H6ST2_HUMAN',
#  'ZNT7_HUMAN',
#  'TRM1_HUMAN',
#  'NIN_HUMAN',
#  'ZDHC5_HUMAN',
#  'PKP2_HUMAN',
#  'DCTP1_HUMAN',
#  'TAPT1_HUMAN',
#  'CENPF_HUMAN',
#  'GRAP1_HUMAN',
#  'ERGI1_HUMAN',
#  'FKBP7_HUMAN',
#  'MYOME_HUMAN',
#  'VPS39_HUMAN',
#  'FA8A1_HUMAN',
#  'MIPO1_HUMAN',
#  'PRC2B_HUMAN',
#  'ZCH18_HUMAN',
#  'FBN2_HUMAN',
#  'SIL1_HUMAN',
#  'RETR3_HUMAN',
#  'LAR4B_HUMAN',
#  'FA98A_HUMAN']

# %%
g.df_pdb_ranking.index
# Out:
# Index(['AASS_HUMAN', 'AASS_HUMAN', 'AASS_HUMAN', 'AATF_HUMAN', 'ACADM_HUMAN',
#        'ACADM_HUMAN', 'ACADM_HUMAN', 'ACADM_HUMAN', 'ACADM_HUMAN',
#        'ACADM_HUMAN',
#        ...
#        'TPA_HUMAN', 'TPA_HUMAN', 'TPA_HUMAN', 'TPA_HUMAN', 'TPA_HUMAN',
#        'TPA_HUMAN', 'TPA_HUMAN', 'U3IP2_HUMAN', 'U3IP2_HUMAN', 'UBP13_HUMAN'],
#       dtype='object', name='gene', length=2262)

# %% [markdown]
# ## Run Clus Pro

# %%
import os
import glob
import time
import cluspro_api

# %%
interactions_with_available_structures = df.loc[df['Uniprot Protein ID'].isin(g.df_pdb_ranking.index)]
interactions_with_available_structures
# Out:
#                 Bait   Preys PreyGene      MIST  Saint_BFDR  AvgSpec  \
# 1        SARS-CoV2 E  O60885     BRD4  0.978488        0.00     2.67
# 2        SARS-CoV2 E  P25440     BRD2  0.906593        0.00     7.00
# 3        SARS-CoV2 E  Q6UX04    CWC27  0.893109        0.03     2.67
# 9        SARS-CoV2 M  P11310    ACADM  0.724349        0.00     2.67
# 10       SARS-CoV2 M  P13804     ETFA  0.718398        0.00     2.33
# ..               ...     ...      ...       ...         ...      ...
# 305  SARS-CoV2 orf9b  Q9UL15     BAG5  0.864650        0.00     6.67
# 309  SARS-CoV2 orf9c  P33527    ABCC1  0.780000        0.00    12.67
# 310  SARS-CoV2 orf9c  P55085    F2RL1  0.891879        0.00     3.67
# 317  SARS-CoV2 orf9c  Q86UT6    NLRX1  0.931986        0.00    11.67
# 330  SARS-CoV2 orf9c  Q9Y6M9   NDUFB9  0.966178        0.04     2.33
#
#      FoldChange Uniprot Protein ID  \
# 1         26.67         BRD4_HUMAN
# 2         70.00         BRD2_HUMAN
# 3         26.67        CWC27_HUMAN
# 9         26.67        ACADM_HUMAN
# 10        23.33         ETFA_HUMAN
# ..          ...                ...
# 305       66.67         BAG5_HUMAN
# 309      126.67         MRP1_HUMAN
# 310       36.67         PAR2_HUMAN
# 317      116.67        NLRX1_HUMAN
# 330       23.33        NDUB9_HUMAN
#
#                            Uniprot Protein Description  \
# 1     Bromodomain-containing protein 4 (Protein HUNK1)
# 2    Bromodomain-containing protein 2 (O27.1.1) (Re...
# 3    Spliceosome-associated protein CWC27 homolog (...
# 9    Medium-chain specific acyl-CoA dehydrogenase, ...
# 10   Electron transfer flavoprotein subunit alpha, ...
# ..                                                 ...
# 305  BAG family molecular chaperone regulator 5 (BA...
# 309  Multidrug resistance-associated protein 1 (EC ...
# 310  Proteinase-activated receptor 2 (PAR-2) (Coagu...
# 317  NLR family member X1 (Caterpiller protein 11.3...
# 330  NADH dehydrogenase [ubiquinone] 1 beta subcomp...
#
#                                       Uniprot Function  \
# 1     Chromatin reader protein that recognizes and ...
# 2     May play a role in spermatogenesis or follicu...
# 3     As part of the spliceosome, plays a role in p...
# 9     Acyl-CoA dehydrogenase specific for acyl chai...
# 10    Heterodimeric electron transfer flavoprotein ...
# ..                                                 ...
# 305   Inhibits both auto-ubiquitination of PRKN and...
# 309   Mediates export of organic anions and drugs f...
# 310   Receptor for trypsin and trypsin-like enzymes...
# 317   Participates in antiviral signaling. Acts as ...
# 330   Accessory subunit of the mitochondrial membra...
#
#                                       Structures (PDB)  \
# 1    2I8N;2LSP;2MJV;2N3K;2NCZ;2ND0;2ND1;2NNU;2OSS;2...
# 2    1X0J;2DVQ;2DVR;2DVS;2DVV;2E3K;2G4A;2YDW;2YEK;3...
# 3                        2HQ6;4R3E;5Z56;5Z58;6FF4;6FF7
# 9                        1EGC;1EGD;1EGE;1T9G;2A1T;4P13
# 10                                 1EFV;1T9G;2A1T;2A1U
# ..                                                 ...
# 305                                          2D9D;3A8Y
# 309                                          2CBZ;4C3Z
# 310                                     5NDD;5NDZ;5NJ6
# 317                                               3UN9
# 330                                5XTC;5XTD;5XTH;5XTI
#
#                            Uniprot Function in Disease
# 1     Note=A chromosomal aberration involving BRD4 ...
# 2                                                  NaN
# 3     Retinitis pigmentosa with or without skeletal...
# 9     Acyl-CoA dehydrogenase medium-chain deficienc...
# 10    Glutaric aciduria 2A (GA2A) [MIM:231680]: An ...
# ..                                                 ...
# 305                                                NaN
# 309                                                NaN
# 310                                                NaN
# 317                                                NaN
# 330   Mitochondrial complex I deficiency, nuclear t...
#
# [139 rows x 12 columns]

# %%
df['Bait'].unique()
# Out:
# array(['SARS-CoV2 E', 'SARS-CoV2 M', 'SARS-CoV2 N', 'SARS-CoV2 Spike',
#        'SARS-CoV2 nsp1', 'SARS-CoV2 nsp10', 'SARS-CoV2 nsp11',
#        'SARS-CoV2 nsp12', 'SARS-CoV2 nsp13', 'SARS-CoV2 nsp14',
#        'SARS-CoV2 nsp15', 'SARS-CoV2 nsp2', 'SARS-CoV2 nsp4',
#        'SARS-CoV2 nsp5', 'SARS-CoV2 nsp5_C145A', 'SARS-CoV2 nsp6',
#        'SARS-CoV2 nsp7', 'SARS-CoV2 nsp8', 'SARS-CoV2 nsp9',
#        'SARS-CoV2 orf10', 'SARS-CoV2 orf3a', 'SARS-CoV2 orf3b',
#        'SARS-CoV2 orf6', 'SARS-CoV2 orf7a', 'SARS-CoV2 orf8',
#        'SARS-CoV2 orf9b', 'SARS-CoV2 orf9c'], dtype=object)

# %%
korkin_dict = {'SARS-CoV2 E': 'wE-',
              'SARS-CoV2 M': 'wM-',
              'SARS-CoV2 N': 'wN-',
              'SARS-CoV2 Spike': 'wS-', 
              'SARS-CoV2 nsp1': 'wNsp1-',
              'SARS-CoV2 nsp10': 'wNsp10-', 
              'SARS-CoV2 nsp11': 'wNsp11-', 
              'SARS-CoV2 nsp12': 'wNsp12-', 
              'SARS-CoV2 nsp13': 'wNsp13-', 
              'SARS-CoV2 nsp14': 'wNsp14-', 
              'SARS-CoV2 nsp15': 'wNsp15-', 
              'SARS-CoV2 nsp2': 'wNsp2-',
              'SARS-CoV2 nsp4': 'wNsp4-',
              'SARS-CoV2 nsp5': 'wNsp5-', 
              'SARS-CoV2 nsp5_C145A': 'wNsp5-', 
              'SARS-CoV2 nsp6': 'wNsp6-',
              'SARS-CoV2 nsp7': 'wNsp7-', 
              'SARS-CoV2 nsp8': 'wNsp8-', 
              'SARS-CoV2 nsp9': 'wNsp9-',
              'SARS-CoV2 orf10': 'wORF10-', 
              'SARS-CoV2 orf3a': 'wORF3a-', 
              'SARS-CoV2 orf3b': 'wORF3b-',  
              'SARS-CoV2 orf6': 'wORF6-',
              'SARS-CoV2 orf7a': 'wORF7a-',
              'SARS-CoV2 orf8': 'wORF8-',
              'SARS-CoV2 orf9b': 'wORF9b-',
              'SARS-CoV2 orf9c': 'wORF9c-'
              }     

modeller_dict = {}
alpha_fold_dict = {}

# %%
g.df_pdb_ranking
# Out:
#             pdb_id pdb_chain_id uniprot experimental_method  resolution  \
# gene
# AASS_HUMAN    5l78            A  Q9UDR5   X-ray diffraction        2.68
# AASS_HUMAN    5o1n            A  Q9UDR5   X-ray diffraction        2.28
# AASS_HUMAN    5o1o            B  Q9UDR5   X-ray diffraction        2.48
# AATF_HUMAN    5w6a            F  Q9NY61   X-ray diffraction        1.74
# ACADM_HUMAN   4p13            A  P11310   X-ray diffraction        1.73
# ...            ...          ...     ...                 ...         ...
# TPA_HUMAN     1bda            B  P00750   X-ray diffraction        3.35
# TPA_HUMAN     1a5h            A  P00750   X-ray diffraction        2.90
# U3IP2_HUMAN   4jxm            A  O43818   X-ray diffraction        1.92
# U3IP2_HUMAN   4j0w            A  O43818   X-ray diffraction        1.70
# UBP13_HUMAN   2l80            A  Q92995        Solution NMR         NaN
#
#              coverage              taxonomy_name  start  end  unp_start  \
# gene
# AASS_HUMAN      0.510               Homo sapiens     26  497        455
# AASS_HUMAN      0.510               Homo sapiens     26  497        455
# AASS_HUMAN      0.510               Homo sapiens     26  497        455
# AATF_HUMAN      0.016  Homo sapiens;Homo sapiens      1    9        539
# ACADM_HUMAN     0.919               Homo sapiens      1  387         35
# ...               ...                        ...    ...  ...        ...
# TPA_HUMAN       0.491               Homo sapiens      1  265        298
# TPA_HUMAN       0.467  Homo sapiens;Homo sapiens      1  252        311
# U3IP2_HUMAN     0.743               Homo sapiens     19  371        118
# U3IP2_HUMAN     0.714               Homo sapiens      5  343        137
# UBP13_HUMAN     0.132               Homo sapiens      3  116        188
#
#              unp_end  rank
# gene
# AASS_HUMAN       926     3
# AASS_HUMAN       926     1
# AASS_HUMAN       926     2
# AATF_HUMAN       547     1
# ACADM_HUMAN      421    21
# ...              ...   ...
# TPA_HUMAN        562     1
# TPA_HUMAN        562     2
# U3IP2_HUMAN      470     1
# U3IP2_HUMAN      475     2
# UBP13_HUMAN      301     1
#
# [2262 rows x 12 columns]

# %%
def create_cluspro_queries(interaction_df, human_protein_df, sars_mapping_dict, sars_structure_path):
    query_list = []
    
    # Select best human protein structures
    human_protein_df = human_protein_df.loc[human_protein_df['rank'] == 1]
    
    # Subset interaction df to available structures
    sars_structure_files = [f for f in os.listdir(sars_structure_path) if f.endswith('.pdb')]
        
    # Maps SARS proteins to structures
    mapping = [glob.glob(os.path.join(sars_structure_path, f + '*.pdb')) for f in interaction_df['Bait'].map(sars_mapping_dict)]
    interaction_df['mapping'] = mapping
    interaction_df = interaction_df[interaction_df['mapping'].map(lambda d: len(d)) > 0]
    
    
    # Iterate over interaction pairs to construct queries
    for row in range(len(interaction_df)):
        interaction_pair = interaction_df.iloc[row]
        
        try:
            human_protein = human_protein_df.loc[interaction_pair['Uniprot Protein ID']]['pdb_id']
            
            for mapping in interaction_pair['mapping']:
                query = f'cluspro_submit --receptor {mapping} --ligpdb {human_protein} --username arian --secret 4HBSKRtJ'
                #piper_qiery = 
                query_list.append(query)
            print(query)
        except:
            continue
            
    return query_list
                        
    
create_cluspro_queries(interaction_df=interactions_with_available_structures,
                       human_protein_df=g.df_pdb_ranking,
                       sars_mapping_dict=korkin_dict,
                       sars_structure_path=sars_structure_path)
# Out:
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 6dne --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 4uyg --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 6ff4 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4jxm --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4f02 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6hmd --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4dgl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4fcj --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 5v87 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6ff7 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 2wjy --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6ek0 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 5exr --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4mhq --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4rr2 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4y97 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp10-2g9tA.pdb --ligpdb 3mbg --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp10-2g9tA.pdb --ligpdb 6bnt --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 6icz --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 4neu --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 4jol --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 2ok3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3ci9 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 2d68 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5h78 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3ovv --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 1gxr --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6iw8 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5fcn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3bbp --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 2l80 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6g8t --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5cx3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6nt9 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 3hg3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 6i0m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 5bwl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 1gy5 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 2a5d --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 2gwf --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2wk3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2bsk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2bsk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 3ner --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1umk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 2bov --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4pyi --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4kyi --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1t91 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5szi --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1z0a --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5szj --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4drz --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5c4m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 3tkl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4pnk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4tvs --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 6fw2 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5kiw --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1x3s --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5wrw --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5lsu --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 1jid --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5l3q --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 4wkr --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 6dcc --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 4zdl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5w6a --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2dk3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5iyb --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 1uzk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 3fmp --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4xi7 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4u7i --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 3zke --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4ndn --username arian --secret 4HBSKRtJ
# ['cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 6dne --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 4uyg --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 6ff4 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 4jxm --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4jxm --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 4f02 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4f02 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 6hmd --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6hmd --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 4dgl --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4dgl --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 4fcj --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4fcj --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 5v87 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 5v87 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 6ff7 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6ff7 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 2wjy --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 2wjy --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Cterminal_domain-2jw8A.pdb --ligpdb 6ek0 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6ek0 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 5exr --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4mhq --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4rr2 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4y97 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp10-2g9tA.pdb --ligpdb 3mbg --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp10-2g9tA.pdb --ligpdb 6bnt --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 6icz --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 4neu --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 4jol --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 2ok3 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3ci9 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 2d68 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5h78 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3ovv --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 1gxr --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6iw8 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5fcn --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3bbp --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 2l80 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6g8t --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5cx3 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6nt9 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 3hg3 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 6i0m --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 5bwl --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 1gy5 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 2a5d --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 2gwf --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2wk3 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2bsk --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2bsk --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 3ner --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1umk --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 2bov --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4pyi --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4kyi --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1t91 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5szi --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1z0a --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5szj --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4drz --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5c4m --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 3tkl --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4pnk --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4tvs --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 6fw2 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5kiw --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1x3s --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5wrw --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5lsu --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 1jid --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5l3q --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 4wkr --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 6dcc --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 4zdl --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5w6a --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2dk3 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5iyb --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 1uzk --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 3fmp --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4xi7 --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4u7i --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 3zke --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ',
#  'cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4ndn --username arian --secret 4HBSKRtJ']

# %%
sars_structure_path = '../structures/korkin_lab/IndividualModels/'


query_list = create_cluspro_queries(interaction_df=interactions_with_available_structures,
                       human_protein_df=g.df_pdb_ranking,
                       sars_mapping_dict=korkin_dict,
                       sars_structure_path=sars_structure_path)
# Out:
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 6dne --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 4uyg --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 6ff4 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4jxm --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4f02 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6hmd --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4dgl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 4fcj --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 5v87 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6ff7 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 2wjy --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wN-Nterminal_domain-1ssk_4ud1A.pdb --ligpdb 6ek0 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 5exr --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4mhq --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4rr2 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp1-2hsxA.pdb --ligpdb 4y97 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp10-2g9tA.pdb --ligpdb 3mbg --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp10-2g9tA.pdb --ligpdb 6bnt --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 6icz --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 4neu --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 4jol --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp12-6nurA.pdb --ligpdb 2ok3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3ci9 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 2d68 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5h78 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3ovv --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 1gxr --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6iw8 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5fcn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 3bbp --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 2l80 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6g8t --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 5cx3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp13-6jytA.pdb --ligpdb 6nt9 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 3hg3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 6i0m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp14-5c8uB.pdb --ligpdb 5bwl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 1gy5 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 2a5d --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp15-2h85A.pdb --ligpdb 2gwf --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2wk3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2bsk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp4-3vc8A.pdb --ligpdb 2bsk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 3ner --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1umk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 2bov --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4pyi --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4kyi --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1t91 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5szi --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1z0a --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5szj --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4drz --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5c4m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 3tkl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4pnk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 4tvs --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 6fw2 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 5kiw --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp7-1ysyA.pdb --ligpdb 1x3s --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5wrw --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5lsu --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 1jid --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5l3q --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 4wkr --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 6dcc --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 4zdl --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 5w6a --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2dk3 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 2nn6 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp8-6nurA.pdb --ligpdb 3j9m --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5iyb --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 1uzk --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 3fmp --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4xi7 --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4u7i --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 3zke --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 5ijn --username arian --secret 4HBSKRtJ
# cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wNsp9-3ee7.pdb --ligpdb 4ndn --username arian --secret 4HBSKRtJ

# %%
def submit_queries(query_list):
    for query in query_list:
        print(f'Running Query: {query}')
        # !$query
        time.sleep(5)
    print('Queries submitted')   
    
submit_queries(query_list[0:2])
# Out:
# Running Query: cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 6dne --username arian --secret 4HBSKRtJ
# ['Incorrect signiature']
# Running Query: cluspro_submit --receptor ../structures/korkin_lab/IndividualModels/wE-5x29A.pdb --ligpdb 4uyg --username arian --secret 4HBSKRtJ
# ['Incorrect signiature']
# Queries submitted

# %%
glob.glob(os.path.join(sars_structure_path, 'wE-*.pdb'))
# Out:
# ['../structures/korkin_lab/IndividualModels/wE-5x29A.pdb']

# %%
korkin_dict.items()
# Out:
# dict_items([('SARS-CoV2 E', 'wE-'), ('SARS-CoV2 M', 'wM-'), ('SARS-CoV2 N', 'wN-'), ('SARS-CoV2 Spike', 'wS-'), ('SARS-CoV2 nsp1', 'wNsp1-'), ('SARS-CoV2 nsp10', 'wNsp10-'), ('SARS-CoV2 nsp11', 'wNsp11-'), ('SARS-CoV2 nsp12', 'wNsp12-'), ('SARS-CoV2 nsp13', 'wNsp13-'), ('SARS-CoV2 nsp14', 'wNsp14-'), ('SARS-CoV2 nsp15', 'wNsp15-'), ('SARS-CoV2 nsp2', 'wNsp2-'), ('SARS-CoV2 nsp4', 'wNsp4-'), ('SARS-CoV2 nsp5', 'wNsp5-'), ('SARS-CoV2 nsp5_C145A', 'wNsp5-'), ('SARS-CoV2 nsp6', 'wNsp6-'), ('SARS-CoV2 nsp7', 'wNsp7-'), ('SARS-CoV2 nsp8', 'wNsp8-'), ('SARS-CoV2 nsp9', 'wNsp9-'), ('SARS-CoV2 orf10', 'wORF10-'), ('SARS-CoV2 orf3a', 'wORF3a-'), ('SARS-CoV2 orf3b', 'wORF3b-'), ('SARS-CoV2 orf6', 'wORF6-'), ('SARS-CoV2 orf7a', 'wORF7a-'), ('SARS-CoV2 orf8', 'wORF8-'), ('SARS-CoV2 orf9b', 'wORF9b-'), ('SARS-CoV2 orf9c', 'wORF9c-')])

# %%
# Run jobs in batches of 50 to prevent overloading cluspro
#print(interactions_with_available_structures)


for row in range(50):
    
    #
    uniprot_id = interactions_with_available_structures.iloc[row]['Uniprot Protein ID'] 
    
    bait_pdb = g.df_pdb_ranking.loc[[uniprot_id]]
    
    #'pdb_id'].loc[g.df_pdb_ranking['rank'] == 1 and g.df_pdb_ranking.index == uniprot_id]
    print(bait_pdb)
    #print()
    
    #Wait 5 secs before next request
    time.sleep(5)
